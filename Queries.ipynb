# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from matplotlib import dates,cm
import matplotlib.ticker as ticker
import datetime as dt
import numpy as np
import pandas as pd
from pandas import DataFrame
import json
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect,or_

# %%
engine = create_engine("sqlite:///database/omdbdatabase.sqlite")
inspector = inspect(engine)

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['actor', 'movies']

# %%
# Save references to each table
Actor = Base.classes.actor
Movies = Base.classes.movies
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
selection = "Morgan Freeman"

data = session.query(Actor.gender,Actor.rank,Movies.title,Actor.credit,Movies.plot,Movies.imdb_rating,Movies.box_office,\
                     Movies.type,Movies.released,Movies.runtime,Movies.genre,Movies.rt_rating).\
                    filter(Movies.imdb_id == Actor.imdb_id).\
                    filter(Actor.name == selection).all()
data
# Out:
# [('male',
#   1,
#   'The Comeback Trail',
#   'actor',
#   'Two movie producers who owe money to the mob, set up their aging movie star for an insurance scam to try and save themselves but winding up getting more than they ever imagined.',
#   None,
#   None,
#   'movie',
#   None,
#   None,
#   'Action',
#   None),
#  ('male',
#   1,
#   'Angel Has Fallen',
#   'actor',
#   'Secret Service Agent Mike Banning is framed for the attempted assassination of the President and must evade his own agency and the FBI as he tries to uncover the real threat.',
#   None,
#   None,
#   'movie',
#   '2019-08-23',
#   None,
#   'Action, Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'The Nutcracker and the Four Realms',
#   'actor',
#   'A young girl is transported into a magical world of gingerbread soldiers and an army of mice.',
#   55.0,
#   None,
#   'movie',
#   '2018-11-02',
#   '99 min',
#   'Adventure, Family, Fantasy',
#   None),
#  ('male',
#   1,
#   'Just Getting Started',
#   'actor',
#   'A two-hander action comedy in the vein of Midnight Run (1988), about an ex-F.B.I. Agent (Tommy Lee Jones) and an ex-mob lawyer in the Witness Protection Program (Morgan Freeman) having to put aside their petty rivalry on the golf course to fend off a mob hit.',
#   44.0,
#   None,
#   'movie',
#   '2017-12-08',
#   '91 min',
#   'Action, Comedy',
#   None),
#  ('male',
#   1,
#   'Going in Style',
#   'actor',
#   'Desperate to pay the bills and come through for their loved ones, three lifelong pals risk it all by embarking on a daring bid to knock off the very bank that absconded with their money.',
#   66.0,
#   None,
#   'movie',
#   '2017-04-07',
#   '96 min',
#   'Comedy, Crime',
#   None),
#  ('male',
#   1,
#   'Now You See Me 2',
#   'actor',
#   'The Four Horsemen resurface, and are forcibly recruited by a tech genius to pull off their most impossible heist yet.',
#   65.0,
#   65030563.0,
#   'movie',
#   '2016-06-10',
#   '129 min',
#   'Action, Adventure, Comedy, Crime, Mystery, Thriller',
#   None),
#  ('male',
#   1,
#   'Momentum',
#   'actor',
#   'Alex, a mysterious thief, is pulled in by her former partner for one last heist. She quickly finds it was never just about the diamonds. A brutal murder sparks a cat and mouse chase between...',
#   55.0,
#   None,
#   'movie',
#   '2015-10-16',
#   '96 min',
#   'Action, Crime, Thriller',
#   None),
#  ('male',
#   1,
#   'Last Knights',
#   'actor',
#   'A fallen warrior rises against a corrupt and sadistic ruler to avenge his dishonored master.',
#   62.0,
#   None,
#   'movie',
#   '2015-04-03',
#   '115 min',
#   'Action, Adventure, Drama',
#   None),
#  ('male',
#   1,
#   'Dolphin Tale 2',
#   'actor',
#   "The team of people who saved Winter's life reassemble in the wake of her surrogate mother's passing in order to find her a companion so she can remain at the Clearwater Marine Hospital.",
#   64.0,
#   None,
#   'movie',
#   '2014-09-12',
#   '107 min',
#   'Drama, Family',
#   None),
#  ('male',
#   1,
#   'Lucy',
#   'actor',
#   'A woman, accidentally caught in a dark deal, turns the tables on her captors and transforms into a merciless warrior evolved beyond human logic.',
#   64.0,
#   108521370.0,
#   'movie',
#   '2014-07-25',
#   '89 min',
#   'Action, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'Transcendence',
#   'actor',
#   "A scientist's drive for artificial intelligence, takes on dangerous implications when his consciousness is uploaded into one such program.",
#   63.0,
#   23014504.0,
#   'movie',
#   '2014-04-18',
#   '119 min',
#   'Action, Drama, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'Last Vegas',
#   'actor',
#   'Four friends take a break from their day-to-day lives to throw a bachelor party in Las Vegas for their last remaining single pal.',
#   66.0,
#   51434214.0,
#   'movie',
#   '2013-11-01',
#   '105 min',
#   'Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'Oblivion',
#   'actor',
#   "A veteran assigned to extract Earth's remaining resources begins to question what he knows about his mission and himself.",
#   70.0,
#   89021735.0,
#   'movie',
#   '2013-04-19',
#   '124 min',
#   'Action, Adventure, Sci-Fi',
#   None),
#  ('male',
#   1,
#   'The Dark Knight Rises',
#   'actor',
#   "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City, now on the edge of total annihilation, from the brutal guerrilla terrorist Bane.",
#   84.0,
#   448130642.0,
#   'movie',
#   '2012-07-20',
#   '164 min',
#   'Action, Thriller',
#   None),
#  ('male',
#   1,
#   'Dolphin Tale',
#   'actor',
#   'A story centered on the friendship between a boy and a dolphin whose tail was lost in a crab trap.',
#   69.0,
#   65099999.0,
#   'movie',
#   '2011-09-23',
#   '113 min',
#   'Drama, Family',
#   None),
#  ('male',
#   1,
#   'RED',
#   'actor',
#   'When his peaceful life is threatened by a high-tech assassin, former black-ops Agent Frank Moses (Bruce Willis) reassembles his old team in a last ditch effort to survive and uncover his assailants.',
#   71.0,
#   88900000.0,
#   'movie',
#   '2010-10-15',
#   '111 min',
#   'Action, Comedy, Crime, Thriller',
#   None),
#  ('male',
#   1,
#   'Invictus',
#   'actor',
#   'Nelson Mandela, in his first term as the South African President, initiates a unique venture to unite the apartheid-torn land: enlist the national rugby team on a mission to win the 1995 Rugby World Cup.',
#   73.0,
#   37431431.0,
#   'movie',
#   '2009-12-11',
#   '134 min',
#   'Biography, Drama, History, Sport',
#   None),
#  ('male',
#   1,
#   'Thick as Thieves',
#   'actor',
#   'A veteran thief recruits a younger crook to help him pull off one final job in order to repay his debt to the Russian mob.',
#   60.0,
#   None,
#   'movie',
#   '2009-01-09',
#   '104 min',
#   'Action, Crime, Thriller',
#   None),
#  ('male',
#   1,
#   'Wanted',
#   'actor',
#   "A frustrated office worker learns that he is the son of a professional assassin and that he shares his father's superhuman killing abilities.",
#   67.0,
#   134294280.0,
#   'movie',
#   '2008-06-27',
#   '110 min',
#   'Action, Crime, Fantasy, Thriller',
#   None),
#  ('male',
#   1,
#   'The Bucket List',
#   'actor',
#   'Two terminally ill men escape from a cancer ward and head off on a road trip with a wish list of to-dos before they die.',
#   74.0,
#   93500000.0,
#   'movie',
#   '2008-01-11',
#   '97 min',
#   'Adventure, Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'Gone Baby Gone',
#   'actor',
#   "Two Boston area detectives investigate a little girl's kidnapping, which ultimately turns into a crisis both professionally and personally.",
#   77.0,
#   20300218.0,
#   'movie',
#   '2007-10-19',
#   '114 min',
#   'Crime, Drama, Mystery, Thriller',
#   None),
#  ('male',
#   1,
#   'The Contract',
#   'actor',
#   'A father and his son attempt to bring in an assassin to the authorities, but his dangerous associates have other plans.',
#   57.0,
#   None,
#   'movie',
#   '2007-04-05',
#   '96 min',
#   'Action, Crime, Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'Lucky Number Slevin',
#   'actor',
#   "A case of mistaken identity lands Slevin into the middle of a war being plotted by two of the city's most rival crime bosses: The Rabbi and The Boss. Slevin is under constant surveillance by relentless Detective Brikowski as well as the infamous assassin Goodkat and finds himself having to hatch his own ingenious plot to get them before they get him.",
#   78.0,
#   None,
#   'movie',
#   '2006-04-07',
#   '110 min',
#   'Crime, Drama, Mystery, Thriller',
#   None),
#  ('male',
#   1,
#   'Magnificent Desolation: Walking on the Moon 3D',
#   'actor',
#   'This program strives to give the viewer an impression of what it is like to actually be on the moon. It provides a romantic, inspirational depiction of the Apollo astronauts travels on the ...',
#   70.0,
#   32533825.0,
#   'movie',
#   '2005-09-23',
#   '40 min',
#   'Documentary, Animation, Short',
#   None),
#  ('male',
#   1,
#   'Batman Begins',
#   'actor',
#   'You play as Batman and unleash your terror into the heart of criminals battling against foes such as Dr. Crane/Scarecrow, Ras Al Ghul and Carmine Falcone.',
#   82.0,
#   None,
#   'game',
#   '2005-06-14',
#   None,
#   'Action, Adventure, Crime, Fantasy, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'Batman Begins',
#   'actor',
#   'After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.',
#   82.0,
#   204100000.0,
#   'movie',
#   '2005-06-15',
#   '140 min',
#   'Action, Adventure',
#   None),
#  ('male',
#   1,
#   'Unleashed',
#   'actor',
#   'A man enslaved by the mob since childhood and raised into behaving like a human attack dog escapes his captors and attempts to start a new life.',
#   70.0,
#   24380112.0,
#   'movie',
#   '2005-05-13',
#   '103 min',
#   'Action, Crime, Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'Million Dollar Baby',
#   'actor',
#   'A determined woman works with a hardened boxing trainer to become a professional.',
#   81.0,
#   100422786.0,
#   'movie',
#   '2005-01-28',
#   '132 min',
#   'Drama, Sport',
#   None),
#  ('male',
#   1,
#   'The Big Bounce',
#   'actor',
#   "A small-time con artist and a Hawaiian real estate developer's mischevious, enterprising mistress team up for a potential $200,000 score.",
#   49.0,
#   6331346.0,
#   'movie',
#   '2004-01-30',
#   '88 min',
#   'Comedy, Crime',
#   None),
#  ('male',
#   1,
#   'Guilty by Association',
#   'actor',
#   'A man becomes guilty by association. Suspense ensues.',
#   25.0,
#   None,
#   'movie',
#   '2003-07-22',
#   '80 min',
#   'Action, Crime, Drama',
#   None),
#  ('male',
#   1,
#   'Dreamcatcher',
#   'actor',
#   "Friends on a camping trip discover that the town they're vacationing in is being plagued in an unusual fashion by parasitic aliens from outer space.",
#   55.0,
#   33700000.0,
#   'movie',
#   '2003-03-21',
#   '134 min',
#   'Drama, Horror, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'The Sum of All Fears',
#   'actor',
#   "C.I.A. analyst Jack Ryan must stop the plans of a Neo-Nazi faction that threatens to induce a catastrophic conflict between the United States and Russia's newly elected President by detonating a nuclear weapon at a football game in Baltimore, Maryland.",
#   64.0,
#   118471320.0,
#   'movie',
#   '2002-05-31',
#   '124 min',
#   'Action, Drama, Thriller, War',
#   None),
#  ('male',
#   1,
#   'Along Came a Spider',
#   'actor',
#   "When a congressman's daughter under Secret Service protection is kidnapped from a private school, detective Alex Cross investigates the case even though he's recovering from the loss of his partner.",
#   63.0,
#   73587034.0,
#   'movie',
#   '2001-04-06',
#   '104 min',
#   'Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'Nurse Betty',
#   'actor',
#   "Comedy about a widow's post-traumatic obsession with a soap star.",
#   62.0,
#   None,
#   'movie',
#   '2000-09-08',
#   '110 min',
#   'Comedy, Crime, Drama, Romance',
#   None),
#  ('male',
#   1,
#   'Deep Impact',
#   'actor',
#   'Unless a comet can be destroyed before colliding with Earth, only those allowed into shelters will survive. Which people will survive?',
#   62.0,
#   None,
#   'movie',
#   '1998-05-08',
#   '120 min',
#   'Action, Drama, Romance, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'Amistad',
#   'actor',
#   'In 1839, the revolt of Mende captives aboard a Spanish owned ship causes a major controversy in the United States when the ship is captured off the coast of Long Island. The courts must decide whether the Mende are slaves or legally free.',
#   73.0,
#   None,
#   'movie',
#   '1997-12-25',
#   '155 min',
#   'Drama, History',
#   None),
#  ('male',
#   1,
#   'Chain Reaction',
#   'actor',
#   'Two researchers in a green alternative energy project are put on the run when they are framed for murder and treason.',
#   56.0,
#   None,
#   'movie',
#   '1996-08-02',
#   '107 min',
#   'Action, Drama, Sci-Fi, Thriller',
#   None),
#  ('male',
#   1,
#   'Se7en',
#   'actor',
#   'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#   86.0,
#   None,
#   'movie',
#   '1995-09-22',
#   '127 min',
#   'Crime, Drama, Mystery, Thriller',
#   None),
#  ('male',
#   1,
#   'The Shawshank Redemption',
#   'actor',
#   'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#   93.0,
#   None,
#   'movie',
#   '1994-10-14',
#   '142 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'The Power of One',
#   'actor',
#   'An English boy, living in Africa during World War II, through his boxing prowess, becomes a symbol of hope, in a time of war.',
#   72.0,
#   None,
#   'movie',
#   '1992-03-27',
#   '127 min',
#   'Drama, Sport',
#   None),
#  ('male',
#   1,
#   'The True Story of Glory Continues',
#   'actor',
#   None,
#   57.0,
#   None,
#   'movie',
#   None,
#   '46 min',
#   'Documentary, History, War',
#   None),
#  ('male',
#   1,
#   'Robin Hood: Prince of Thieves',
#   'actor',
#   'When Robin and his Moorish companion come to England and the tyranny of the Sheriff of Nottingham, he decides to fight back as an outlaw.',
#   69.0,
#   None,
#   'movie',
#   '1991-06-14',
#   '143 min',
#   'Action, Adventure, Drama, Romance',
#   None),
#  ('male',
#   1,
#   'The Civil War',
#   'actor',
#   'A comprehensive survey of the American Civil War.',
#   91.0,
#   None,
#   'series',
#   '1990-09-23',
#   '680 min',
#   'Documentary, History, War',
#   None),
#  ('male',
#   1,
#   'Glory',
#   'actor',
#   "Robert Gould Shaw leads the U.S. Civil War's first all-black volunteer company, fighting prejudices from both his own Union Army, and the Confederates.",
#   79.0,
#   None,
#   'movie',
#   '1990-02-16',
#   '122 min',
#   'Biography, Drama, History, War',
#   None),
#  ('male',
#   1,
#   'Johnny Handsome',
#   'actor',
#   'After being double crossed and thrown in jail, a deformed gangster gets a new face and rehabilitation, but his desire for revenge looms.',
#   61.0,
#   None,
#   'movie',
#   '1989-09-29',
#   '94 min',
#   'Crime, Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'Clean and Sober',
#   'actor',
#   "A hustling drug addict checks himself into rehab to escape trouble with the law and realizes that it's exactly what he needs.",
#   67.0,
#   None,
#   'movie',
#   '1988-08-10',
#   '124 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Fight for Life',
#   'actor',
#   'Jerry Lewis plays an Ohio optometrist who has a six-year old daughter with epilepsy. He fights to get the FDA to approve a drug (at that time only available in England) for use in the U.S.',
#   57.0,
#   None,
#   'movie',
#   '1987-03-23',
#   '95 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Resting Place',
#   'actor',
#   "The mysterious death of an army officer comes under investigation by Major Kendall Laird as the young soldier's parents seek an honorable burial place, out of respect for their son. The ...",
#   64.0,
#   None,
#   'movie',
#   '1986-04-27',
#   '100 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'The Twilight Zone',
#   'actor',
#   'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#   78.0,
#   None,
#   'series',
#   '1985-09-27',
#   '45 min',
#   'Sci-Fi, Fantasy, Mystery, Thriller, Horror',
#   None),
#  ('male',
#   1,
#   'That Was Then... This Is Now',
#   'actor',
#   'Two juvenile delinquents find themselves growing apart, for one is growing up, and the other is staying young and reckless.',
#   62.0,
#   None,
#   'movie',
#   '1985-11-08',
#   '102 min',
#   'Crime, Drama',
#   None),
#  ('male',
#   1,
#   'The Atlanta Child Murders',
#   'actor',
#   'The city of Atlanta, Georgia, is terrorized by a rash of child murders occurring in its black community. When a black photographer is arrested for the crimes, controversy erupts over ...',
#   67.0,
#   None,
#   'series',
#   '1985-02-10',
#   '245 min',
#   'Crime, Drama, Mystery',
#   None),
#  ('male',
#   1,
#   'Harry & Son',
#   'actor',
#   'Harry Keach has been widowed for two years and works as a demolition crane operator on a demolition crew.',
#   58.0,
#   None,
#   'movie',
#   '1984-03-02',
#   '120 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Death of a Prophet',
#   'actor',
#   'After breaking ties with the Nation of Islam, Malcolm X became a man marked for death...and it was just a matter of time before his enemies closed in. Despite death threats and intimidation...',
#   49.0,
#   None,
#   'movie',
#   '2017-10-27',
#   '60 min',
#   'Drama, History',
#   None),
#  ('male',
#   1,
#   "Ryan's Hope",
#   'actor',
#   "Set in Riverside on the upper West Side of Manhattan, Ryan's Hope centered mostly on the working class Ryans, an Irish-American family headed by Maeve and Johnny Ryan. They owned Ryan's Bar...",
#   72.0,
#   None,
#   'series',
#   '1975-07-07',
#   '30 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Eyewitness',
#   'actor',
#   'Eccentric Vietnam War vet turned janitor claims to have witnessed a murder of a man tied to international political underground in order to get the attention of a TV reporter he has a huge crush on. The cops suspect his loser best friend.',
#   60.0,
#   None,
#   'movie',
#   '1981-02-13',
#   '103 min',
#   'Crime, Drama, Mystery, Romance, Thriller',
#   None),
#  ('male',
#   1,
#   'Attica',
#   'actor',
#   'The behind the scenes of the 1971 prisoners revolt at the Attica prison.',
#   66.0,
#   None,
#   'movie',
#   '1980-03-02',
#   '97 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Julius Caesar',
#   'actor',
#   'The growing ambition of Julius Caesar is a source of major concern to his close friend Brutus. Cassius persuades him to participate in his plot to assassinate Caesar but they have both sorely underestimated Mark Antony.',
#   57.0,
#   None,
#   'movie',
#   None,
#   None,
#   'Drama, History',
#   None),
#  ('male',
#   1,
#   'Visions',
#   'actor',
#   'Weekly anthology series of original dramas, often with period settings.',
#   59.0,
#   None,
#   'series',
#   '1976-10-21',
#   None,
#   'Drama',
#   None),
#  ('male',
#   1,
#   'The Electric Company',
#   'actor',
#   'A comedy variety show that teaches basic phonetic and grammar concepts using live-action sketches, cartoons, songs, and Spider-Man episodes.',
#   82.0,
#   None,
#   'series',
#   '1971-10-25',
#   '28 min',
#   'Family, Comedy',
#   None),
#  ('male',
#   1,
#   "Who Says I Can't Ride a Rainbow!",
#   'actor',
#   'Barney (Jack Klugman) owns the last working farm in Manhattan. For various reasons, city officials have decided to close it down. A special event is planned to raise awareness and money to ...',
#   60.0,
#   None,
#   'movie',
#   '1971-11-18',
#   '85 min',
#   'Family, Drama',
#   None),
#  ('male',
#   1,
#   'New York Television Theatre',
#   'actor',
#   None,
#   None,
#   None,
#   'series',
#   None,
#   None,
#   'Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'A Man Called Adam',
#   'actor',
#   'A famous jazz trumpeter finds himself unable to cope with the problems of everyday life.',
#   65.0,
#   None,
#   'movie',
#   '1967-12-07',
#   '99 min',
#   'Drama, Music',
#   None),
#  ('male',
#   1,
#   'Madam Secretary',
#   'producer',
#   'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#   76.0,
#   None,
#   'series',
#   '2014-09-21',
#   '45 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Through the Wormhole',
#   'producer',
#   'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#   86.0,
#   None,
#   'series',
#   '2010-06-09',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   '5 Flights Up',
#   'producer',
#   "A long-time married couple who've spent their lives together in the same New York apartment become overwhelmed by personal and real estate-related issues when they plan to move away.",
#   62.0,
#   None,
#   'movie',
#   '2015-05-08',
#   '88 min',
#   'Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'Stem Cell Universe with Stephen Hawking',
#   'producer',
#   'Led by a pioneer in the science world, Stephen Hawking, this special takes us on a journey which delves into the subjects of stem cells both embryonic and adult to explore what these ...',
#   82.0,
#   None,
#   'movie',
#   '2014-02-03',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   '30 for 30',
#   'producer',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None,
#   'series',
#   '2009-10-06',
#   '60 min',
#   'Documentary, Biography, History, Sport',
#   None),
#  ('male',
#   1,
#   'The Maiden Heist',
#   'producer',
#   'A comedy centered on three museum security guards who devise a plan to steal back the artworks to which they have become attached after they are transferred to another museum.',
#   61.0,
#   481378.0,
#   'movie',
#   '2010-07-08',
#   '90 min',
#   'Comedy, Crime',
#   None),
#  ('male',
#   1,
#   'Levity',
#   'producer',
#   'After two decades in prison for murder, a man is released on parole and returns to his hometown seeking redemption.',
#   64.0,
#   None,
#   'movie',
#   '2003-08-29',
#   '100 min',
#   'Crime, Drama',
#   None),
#  ('male',
#   1,
#   'Under Suspicion',
#   'producer',
#   'A lawyer is asked to come to the police station to clear up a few loose ends in his witness report of a foul murder. This will only take ten minutes, they say, but it turns out to be one ...',
#   65.0,
#   None,
#   'movie',
#   '2000-11-15',
#   '110 min',
#   'Crime, Drama, Thriller',
#   None),
#  ('male',
#   1,
#   'Going in Style',
#   'soundtrack',
#   'Desperate to pay the bills and come through for their loved ones, three lifelong pals risk it all by embarking on a daring bid to knock off the very bank that absconded with their money.',
#   66.0,
#   None,
#   'movie',
#   '2017-04-07',
#   '96 min',
#   'Comedy, Crime',
#   None),
#  ('male',
#   1,
#   '10 Items or Less',
#   'soundtrack',
#   'An actor (Freeman) prepping for an upcoming role meets a quirky grocery clerk (Vega), and the pair hit the road to show one another their respective worlds.',
#   66.0,
#   69265.0,
#   'movie',
#   '2007-02-08',
#   '82 min',
#   'Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'Madam Secretary',
#   'director',
#   'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#   76.0,
#   None,
#   'series',
#   '2014-09-21',
#   '45 min',
#   'Drama',
#   None),
#  ('male',
#   1,
#   'Raise My Hands',
#   'miscellaneous',
#   'A tribute to a man who stood against apartheid, and changed the world.',
#   None,
#   None,
#   'movie',
#   None,
#   '9 min',
#   'Documentary, Short, Biography',
#   None),
#  ('male',
#   1,
#   'Now You See Me 2: Bringing Magic to Life',
#   'thanks',
#   'A philosophical musings about the wonder of magic.',
#   None,
#   None,
#   'movie',
#   '2016-09-06',
#   '16 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'The Last White Knight',
#   'thanks',
#   'In 1965, 21-year-old Torontonian, Paul Saltzman drove to Mississippi, volunteering as a civil rights worker with the Student Non-Violent Coordinating Committee. He was arrested, spending 10...',
#   72.0,
#   None,
#   'movie',
#   '2013-07-31',
#   '78 min',
#   'Documentary, Biography, History',
#   None),
#  ('male',
#   1,
#   'Biography: Morgan Freeman',
#   'thanks',
#   None,
#   None,
#   None,
#   'movie',
#   None,
#   None,
#   'Biography',
#   None),
#  ('male',
#   1,
#   'Strength and Honour',
#   'thanks',
#   "A single father decides to break his dying wife's last wish to not box again in order to save his young son from certain death.",
#   60.0,
#   51933.0,
#   'movie',
#   '2007-11-30',
#   '95 min',
#   'Action, Drama',
#   None),
#  ('male',
#   1,
#   'Bobby Rush: Live at Ground Zero',
#   'thanks',
#   'Bobby Rush, a fifty-year veteran of the blues "chitlin\' circuit" performs a set at the Ground Zero Blues Club in Clarksdale, Mississippi.',
#   None,
#   None,
#   'movie',
#   '2007-04-03',
#   '74 min',
#   'Music',
#   None),
#  ('male',
#   1,
#   'Scandalize My Name: Stories from the Blacklist',
#   'thanks',
#   'A documentary look at the confluence of the Red scare, McCarthyism, and blacklists with the post-war activism by African Americans seeking more and better roles on radio, television, and ...',
#   79.0,
#   None,
#   'movie',
#   None,
#   '54 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Panama Canal in 3D a Land Divided a World United',
#   'self',
#   'Through the magic of 3D and IMAX cameras, audiences everywhere can take a mind-blowing trip through one of the seven wonders of the modern world in PANAMA CANAL 3D: A LAND DIVIDED A WORLD ...',
#   None,
#   None,
#   'movie',
#   None,
#   '45 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Jimmy Kimmel Live!',
#   'self',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None,
#   'series',
#   '2003-01-26',
#   '60 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The 24th Annual Screen Actors Guild Awards',
#   'self',
#   None,
#   85.0,
#   None,
#   'movie',
#   '2018-01-21',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Golden Globes 75th Anniversary Special',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2017-12-13',
#   '120 min',
#   'Documentary, Comedy, Reality-TV',
#   None),
#  ('male',
#   1,
#   'The Late Late Show with James Corden',
#   'self',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None,
#   'series',
#   '2015-03-23',
#   '60 min',
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Dr. Oz Show',
#   'self',
#   'Dr. Oz delivers health tips you may have received from your doctor in the form of a talk show.',
#   47.0,
#   None,
#   'series',
#   '2009-09-14',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'CBS This Morning',
#   'self',
#   'A mix of news, features and interviews with notable figures in politics, business and entertainment.',
#   57.0,
#   None,
#   'series',
#   '2012-01-09',
#   '120 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'Entertainment Tonight',
#   'self',
#   '"Entertainment Tonight" is the #1 syndicated entertainment newsmagazine in the world. Launched in 1981, ET is anchored by Mary Hart and Bob Goen. Primary substitute anchors are Jann Carl ...',
#   37.0,
#   None,
#   'series',
#   '1981-09-14',
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'Celebrity Page',
#   'self',
#   'A look at the top stories in entertainment and celebrity news.',
#   53.0,
#   None,
#   'series',
#   '2013-09-09',
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'Through the Wormhole',
#   'self',
#   'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#   86.0,
#   None,
#   'series',
#   '2010-06-09',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The View',
#   'self',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None,
#   'series',
#   '1997-08-11',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Late Night with Seth Meyers',
#   'self',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None,
#   'series',
#   '2014-02-24',
#   '60 min',
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Tonight Show Starring Jimmy Fallon',
#   'self',
#   'Jimmy Fallon hosts the Tonight Show and interviews celebrities, plays games with them and has a musical or comedic guest perform.',
#   74.0,
#   None,
#   'series',
#   '2014-02-17',
#   '60 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Age of Spin: Dave Chappelle Live at the Hollywood Palladium',
#   'self',
#   'Dave Chappelle gives his usual skewed insight into the topics of race, technology, OJ Simpson, and more in a stand up special filmed in Hollywood.',
#   80.0,
#   None,
#   'movie',
#   '2017-03-21',
#   '67 min',
#   'Documentary, Comedy',
#   None),
#  ('male',
#   1,
#   'National Endowment for the Arts: United States of Arts',
#   'self',
#   None,
#   None,
#   None,
#   'series',
#   '2015-09-25',
#   None,
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Live! with Kelly',
#   'self',
#   'This popular and long-running morning talk show owes much of its success to the chemistry between its two hosts, Regis Philbin and Kelly Ripa. Although the format is not significantly ...',
#   48.0,
#   None,
#   'series',
#   None,
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Now You See Me 2: Bringing Magic to Life',
#   'self',
#   'A philosophical musings about the wonder of magic.',
#   None,
#   None,
#   'movie',
#   '2016-09-06',
#   '16 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Good Morning America',
#   'self',
#   'ABC\'s "Good Morning America" presents the News and Information Source of the day\'s topics and journalism. The 1st Co-Host Team of David Hartman & Nancy Dussault, 2nd was Sandy Hill, 3rd was ...',
#   50.0,
#   None,
#   'series',
#   '1975-01-06',
#   '120 min',
#   'News, Talk-Show',
#   None),
#  ('male',
#   1,
#   "The Making of 'London Has Fallen'",
#   'self',
#   "Making a sequel after the original hit, the new movie's direction and plot, characters and their actions, performances, Babak Najafi's direction, the movie's impressive cast, the logistics ...",
#   None,
#   None,
#   'movie',
#   '2016-06-14',
#   '13 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'The C Word',
#   'self',
#   'A personal, important, surprising, and funny documentary about the industries of death that give us cancer, and the unheralded science of prevention.',
#   74.0,
#   None,
#   'movie',
#   '2016-11-25',
#   '89 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The Oscars',
#   'self',
#   'The 88th Academy Awards ceremony honors achievement in film in 2015.',
#   65.0,
#   None,
#   'movie',
#   '2016-02-28',
#   '217 min',
#   'Comedy, Music',
#   None),
#  ('male',
#   1,
#   '73rd Golden Globe Awards',
#   'self',
#   "The Hollywood Foreign Press Association's 73rd annual event honoring excellence in film and television, hosted by Ricky Gervais.",
#   70.0,
#   None,
#   'movie',
#   '2016-01-10',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   "Oprah's Master Class: Belief Special",
#   'self',
#   None,
#   44.0,
#   None,
#   'movie',
#   '2015-10-11',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'JFK & LBJ: A Time for Greatness',
#   'self',
#   None,
#   None,
#   None,
#   'episode',
#   '2015-08-04',
#   None,
#   'Documentary, History, Mystery',
#   None),
#  ('male',
#   1,
#   'The Nightly Show with Larry Wilmore',
#   'self',
#   'A late night satirical talk show hosted by Larry Wilmore.',
#   55.0,
#   None,
#   'series',
#   '2015-01-19',
#   '22 min',
#   'Comedy, News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Shakespeare Uncovered',
#   'self',
#   'Various actors discuss Shakespeare plays. Each episode is presented by one actor and, in most cases, the actor discusses one play. However, some episodes cover more than one play. For ...',
#   87.0,
#   None,
#   'series',
#   '2012-01-25',
#   '55 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Lucy: The Evolution of Lucy',
#   'self',
#   'The possible occurrence of what might happen should a person attain more than 10 percent of the brains cerebral capacity and increased cellular growth..',
#   67.0,
#   None,
#   'movie',
#   '2015-01-20',
#   '16 min',
#   'Short',
#   None),
#  ('male',
#   1,
#   'SAG Foundation Conversations',
#   'self',
#   None,
#   72.0,
#   None,
#   'series',
#   '1997-07-29',
#   None,
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Late Late Show with Craig Ferguson',
#   'self',
#   'Making a satire out of the entire Late Night Show concept Scotsman Craig Ferguson hosts his show with a robot skeleton and a "horse" as his sidekicks. The show features the stereotypical parts of a Late Show, but all in their own, raw way.',
#   83.0,
#   None,
#   'series',
#   '2005-01-03',
#   '40 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   '2014 Primetime Creative Arts Emmy Awards',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2014-08-24',
#   '205 min',
#   None,
#   None),
#  ('male',
#   1,
#   'The Colbert Report',
#   'self',
#   'Satirical newscaster Stephen Colbert provides humorous commentary on the big issues going on in the United States and the rest of the world, with his larger-than-life ego and overly-patriotic spirit along with him every step of the way.',
#   85.0,
#   None,
#   'series',
#   '2005-10-17',
#   '30 min',
#   'Comedy, News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Up Close with Carrie Keagan',
#   'self',
#   None,
#   53.0,
#   None,
#   'series',
#   '2007-02-21',
#   None,
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Island of Lemurs: Madagascar',
#   'self',
#   "A documentary that follows Dr. Patricia C. Wright's mission to help lemurs, the highly evolved creatures who arrived on Madagascar millions of years ago as castaways but are now highly endangered.",
#   70.0,
#   10675739.0,
#   'movie',
#   '2014-09-05',
#   '39 min',
#   'Documentary, Short, Adventure, Biography, Family',
#   None),
#  ('male',
#   1,
#   'Ask a Badass with Elizabeth Banks',
#   'self',
#   None,
#   70.0,
#   None,
#   'series',
#   '2013-11-22',
#   '4 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   '20th Annual Screen Actors Guild Awards',
#   'self',
#   'Screen Actors Guild Award - American award, awarded by Guild of movie actors of the USA from 1995 for movies and television serials.',
#   70.0,
#   None,
#   'movie',
#   '2014-01-18',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'JFK: A President Betrayed',
#   'self',
#   'Narrated by Academy Award winner Morgan Freeman, "JFK: A President Betrayed" uncovers new evidence that reveals how JFK embarked on secret back channel peace efforts with Nikita Khrushchev ...',
#   75.0,
#   None,
#   'movie',
#   '2013-11-12',
#   '90 min',
#   'Documentary, Drama, History, Mystery',
#   None),
#  ('male',
#   1,
#   "Promise of a New World: The Making of 'Oblivion'",
#   'self',
#   'This terrific five-part "Making Of" documentary. Segments include "Destiny" (the development of the story, Iceland shoot and the film\'s practical sets), "Voyage" (the inspiration, design ...',
#   None,
#   None,
#   'movie',
#   '2013-08-06',
#   '48 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'AFI Life Achievement Award: A Tribute to Mel Brooks',
#   'self',
#   None,
#   68.0,
#   None,
#   'movie',
#   '2013-06-15',
#   '67 min',
#   'Biography',
#   None),
#  ('male',
#   1,
#   'TVGN Movie Special: Now You See Me',
#   'self',
#   "TVGN's Movie Special: Now You See Me is a behind the scenes look at the summer blockbuster movie. From electrifying stunts, to movie secrets straight from the stars,to magic moments ...",
#   78.0,
#   None,
#   'movie',
#   '2013-05-25',
#   '30 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   "Don't Say No Until I Finish Talking: The Story of Richard D. Zanuck",
#   'self',
#   'A look at the life and work of legendary film producer Richard D. Zanuck.',
#   70.0,
#   None,
#   'movie',
#   '2013-04-28',
#   '88 min',
#   'Documentary, Biography',
#   None),
#  ('male',
#   1,
#   'The Tonight Show with Jay Leno',
#   'self',
#   "After Johnny Carson's retirement from the show, Jay Leno stepped in as his permanent replacement. The format of the show has remained largely unchanged, consisting primarily of an opening ...",
#   53.0,
#   None,
#   'series',
#   '1992-05-25',
#   '62 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Tales from the Warner Bros. Lot',
#   'self',
#   'In honor of 90 years of Warner Bros., viewers learn the history of the Hollywood studio and are given a behind-the-scenes tour of the studio grounds (including the famous backlot). Actors, ...',
#   69.0,
#   None,
#   'movie',
#   '2013-01-15',
#   '106 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Ending the Knight',
#   'self',
#   'A comprehensive look into how Director Christopher Nolan and his production team made "The Dark Knight Rises" the epic conclusion to the Dark Knight legend. These cover stunts and action, ...',
#   None,
#   None,
#   'movie',
#   '2012-12-04',
#   '111 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Late Show with David Letterman',
#   'self',
#   'The Late Show with David Letterman is an hour-long weeknight comedy and talk-show broadcast by CBS from the Ed Sullivan Theater on Broadway in New York City.',
#   69.0,
#   None,
#   'series',
#   '1993-08-30',
#   '60 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Michael Douglas & Friends Celebrity Golf Tournament',
#   'self',
#   "The Michael Douglas & Friends celebrity golf tournament has attracted some of the entertainment industry's biggest stars. The tournament has raised over $10 million, and benefits the Motion...",
#   None,
#   None,
#   'movie',
#   '2012-07-07',
#   None,
#   'Sport',
#   None),
#  ('male',
#   1,
#   'Tavis Smiley',
#   'self',
#   "A diverse panel of experts on various social, political, economic, and legal issues that are key to Detroit's turnaround.",
#   56.0,
#   None,
#   'series',
#   '2004-01-05',
#   '30 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   "Universal's Cinematic Spectacular: 100 Years of Movie Memories",
#   'self',
#   None,
#   71.0,
#   None,
#   'movie',
#   '2012-05-08',
#   '18 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'The 84th Annual Academy Awards',
#   'self',
#   'Annual awards presentation honoring the best film achievements of 2011.',
#   73.0,
#   None,
#   'movie',
#   '2012-02-26',
#   None,
#   'Comedy',
#   None),
#  ('male',
#   1,
#   'MSN Exclusives',
#   'self',
#   'A Canadian talk show.',
#   64.0,
#   None,
#   'series',
#   '2012-01-19',
#   '10 min',
#   'Biography, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The 69th Annual Golden Globe Awards',
#   'self',
#   'The annual Golden Globe Awards hosted by Ricky Gervais.',
#   72.0,
#   None,
#   'movie',
#   '2012-01-15',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Piers Morgan Tonight',
#   'self',
#   None,
#   31.0,
#   None,
#   'series',
#   '2011-01-17',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Anderson Live',
#   'self',
#   "it's about a cool guy tellin the news",
#   48.0,
#   None,
#   'series',
#   '2011-09-12',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Curiosity',
#   'self',
#   'This program is made by the Discovery Network, and the show\'s \'full-name\' has the suffix phrase of "The Questions of Our Life", after curiosity. The show tries to answer mysteries and ...',
#   79.0,
#   None,
#   'series',
#   '2011-08-07',
#   '45 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Close Up',
#   'self',
#   'Primarily meant for the Asian market, these collections of biographies were filmed in English, then translated to the various languages of the networks country of origin. Each of the ...',
#   75.0,
#   None,
#   'series',
#   '2011-01-01',
#   '26 min',
#   'Biography',
#   None),
#  ('male',
#   1,
#   'AFI Life Achievement Award: A Tribute to Morgan Freeman',
#   'self',
#   None,
#   68.0,
#   None,
#   'movie',
#   '2011-06-19',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'First: Robotics Promotion',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2011-04-22',
#   None,
#   'Short',
#   None),
#  ('male',
#   1,
#   'The Role That Changed My Life',
#   'self',
#   None,
#   None,
#   None,
#   'series',
#   '2007-10-29',
#   '22 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   '17th Annual Screen Actors Guild Awards',
#   'self',
#   None,
#   67.0,
#   None,
#   'movie',
#   '2011-01-29',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Biography',
#   'self',
#   'The life stories of various historical figures and celebrities are told.',
#   79.0,
#   None,
#   'series',
#   '1987-04-06',
#   '60 min',
#   'Documentary, Biography',
#   None),
#  ('male',
#   1,
#   "The President's Photographer: Fifty Years Inside the Oval Office",
#   'self',
#   'The movie offers a fresh and candid viewpoint on life and work behind the famous facade of 1600 Pennsylvania Avenue.',
#   78.0,
#   None,
#   'movie',
#   '2010-11-24',
#   '52 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'An American Salute: The Pops at 125',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2010-05-31',
#   '30 min',
#   'Documentary, Music',
#   None),
#  ('male',
#   1,
#   'The Oprah Winfrey Show',
#   'self',
#   'Oprah Winfrey hosts a live audience talk-show with celebrity guests and discusses daily stories.',
#   51.0,
#   None,
#   'series',
#   '1986-01-07',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   '41st NAACP Image Awards',
#   'self',
#   None,
#   26.0,
#   None,
#   'movie',
#   '2010-02-26',
#   '120 min',
#   'Family',
#   None),
#  ('male',
#   1,
#   'The Eastwood Factor',
#   'self',
#   'Documentary narrated by Morgan Freeman with Clint Eastwood commenting on his film career as an actor, a director and a song writer. He reviews his long relationship with Warner Brothers ...',
#   68.0,
#   None,
#   'movie',
#   '2010-02-16',
#   '89 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Live from Studio Five',
#   'self',
#   'A live, early evening magazine show dealing with the latest news, celebrity gossip and everything in between.',
#   30.0,
#   None,
#   'series',
#   '2009-09-14',
#   '65 min',
#   'News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Breakfast',
#   'self',
#   "BBC One's flagship morning news programme covering current affairs, business, sports, plus guest interviews and weather reports.",
#   56.0,
#   None,
#   'series',
#   '2000-10-02',
#   '180 min',
#   'Family, News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Días de cine',
#   'self',
#   'Antonio Gasset hosts this show in which recently released movies and DVDs are thoughtfully discussed, in a documentary-like way.',
#   67.0,
#   None,
#   'series',
#   None,
#   '60 min',
#   'News',
#   None),
#  ('male',
#   1,
#   '16th Annual Screen Actors Guild Awards',
#   'self',
#   'Screen Actors Guild Award - American award, awarded by Guild of movie actors of the USA from 1995 for movies and television serials.',
#   67.0,
#   None,
#   'movie',
#   '2010-01-23',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'The 67th Annual Golden Globe Awards',
#   'self',
#   'Welcome to the 67th annual Golden Globe Awards, and your host, Ricky Gervais. You may know him as the man who created The Office...',
#   72.0,
#   None,
#   'movie',
#   '2010-01-17',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'The 7PM Project',
#   'self',
#   "The Project is a TV show joining the latest conversations happening throughout Australia. It's news, but not as you know it.",
#   55.0,
#   None,
#   'series',
#   '2009-07-20',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Rachael Ray',
#   'self',
#   'Rachael Ray offers simple solutions to everyday issues.',
#   44.0,
#   None,
#   'series',
#   '2006-09-18',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Jay Leno Show',
#   'self',
#   None,
#   37.0,
#   None,
#   'series',
#   '2009-09-14',
#   '60 min',
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The 1st Annual Noble Awards',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2009-10-31',
#   '105 min',
#   None,
#   None),
#  ('male',
#   1,
#   'The Code: Behind the Scenes',
#   'self',
#   'This featurette follows the crew through the filming of several scenes and shows director Mimi Leder giving instructions to the main actors.',
#   None,
#   None,
#   'movie',
#   '2009-06-28',
#   '16 min',
#   'Short',
#   None),
#  ('male',
#   1,
#   'The Biggest Loser',
#   'self',
#   'The simple idea of The Biggest Loser, is that "whomever loses the most...wins."',
#   55.0,
#   None,
#   'series',
#   '2004-10-19',
#   '43 min',
#   'Game-Show, Reality-TV',
#   None),
#  ('male',
#   1,
#   'The 51st Annual Grammy Awards',
#   'self',
#   None,
#   66.0,
#   None,
#   'movie',
#   '2009-02-08',
#   None,
#   'Music',
#   None),
#  ('male',
#   1,
#   'Delta Rising: A Blues Documentary',
#   'self',
#   "Delta Rising tells the story of Clarksdale and its importance to the blues, America's classical music. This story is told through the experiences of various musicians in and around ...",
#   None,
#   None,
#   'movie',
#   None,
#   '79 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The Kennedy Center Honors: A Celebration of the Performing Arts',
#   'self',
#   None,
#   80.0,
#   None,
#   'movie',
#   '2008-12-30',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Wanted: Cast and Characters',
#   'self',
#   None,
#   81.0,
#   None,
#   'movie',
#   '2008-12-02',
#   None,
#   'Short',
#   None),
#  ('male',
#   1,
#   'Stephen Fry in America',
#   'self',
#   'English actor-comedian Stephen Fry travels through the US regions by London cab.',
#   80.0,
#   None,
#   'series',
#   '2008-10-12',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'HBO First Look',
#   'self',
#   'Behind-the-scenes look at upcoming feature films, featuring interview commentary with their casts and crews.',
#   61.0,
#   None,
#   'series',
#   '1994-03-01',
#   '13 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Where the Water Meets the Sky',
#   'self',
#   'Narrated by Academy Award winning actor, Morgan Freeman, Where the Water Meets the Sky tells the inspiring story of a group of women from a remote town in northern Zambia who are given a ...',
#   87.0,
#   None,
#   'movie',
#   '2008-06-06',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'African American Lives',
#   'self',
#   'This 4 part PBS series attempts to trace the roots of 8 guests using genealogy, oral history, family stories, and DNA analysis.',
#   75.0,
#   None,
#   'series',
#   '2006-02-01',
#   '54 min',
#   'Documentary, History',
#   None),
#  ('male',
#   1,
#   'Going Home: Behind the Scenes with Ben Affleck',
#   'self',
#   "This program presents the standard mix of movie clips, shots from the set and interviews as we get notes from cast and crew and looks at the story and its adaptation, Affleck's move to the ...",
#   None,
#   None,
#   'movie',
#   '2008-02-12',
#   '7 min',
#   'Short',
#   None),
#  ('male',
#   1,
#   'e2: The Economies of Being Environmentally Conscious',
#   'self',
#   'A six-part series about international efforts to design and build eco-friendly structures through sustainable architecture.',
#   84.0,
#   None,
#   'series',
#   '2006-06-01',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Gone Baby Gone Featurette',
#   'self',
#   None,
#   70.0,
#   None,
#   'movie',
#   '2007-10-10',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Evan Almighty: Becoming Noah',
#   'self',
#   'How Steve Carell was transformed to play the Noah-like figure Evan in the movie Evan Almighty.',
#   62.0,
#   None,
#   'movie',
#   '2007-10-09',
#   None,
#   'Short, Comedy',
#   None),
#  ('male',
#   1,
#   'Evan Almighty: The Almighty Green Set',
#   'self',
#   None,
#   59.0,
#   None,
#   'movie',
#   '2007-10-09',
#   None,
#   'Short, Comedy',
#   None),
#  ('male',
#   1,
#   "Evan Almighty: The Building of Noah's Ark",
#   'self',
#   None,
#   61.0,
#   None,
#   'movie',
#   '2007-10-09',
#   None,
#   'Short, Comedy',
#   None),
#  ('male',
#   1,
#   "Late Night with Conan O'Brien",
#   'self',
#   "Conan O'Brien, a Harvard Lampoon alumnus, hosts this late-night comedy/talk-show, which is often silly and whimsical.",
#   82.0,
#   None,
#   'series',
#   '1993-09-13',
#   '60 min',
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   "AFI's 100 Years... 100 Movies: 10th Anniversary Edition",
#   'self',
#   "This special is a recounting of the top 100 movies of all time, updated from the list of 10 years ago aired in the first AFI's 100 Years... 100 Movies.",
#   66.0,
#   None,
#   'movie',
#   '2007-06-20',
#   '130 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Caiga quien caiga',
#   'self',
#   'Reality changes depending on how you see it. CQC has its own way of seeing things. "Caiga Quien Caiga" is a weekly news roundup that takes a humorous and ironic approach to reporting ...',
#   75.0,
#   None,
#   'series',
#   '1996-05-10',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Corazón de...',
#   'self',
#   None,
#   50.0,
#   None,
#   'series',
#   '1997-07-07',
#   '30 min',
#   None,
#   None),
#  ('male',
#   1,
#   'George Clooney: An American Cinematheque Tribute',
#   'self',
#   None,
#   69.0,
#   None,
#   'movie',
#   '2006-12-13',
#   '75 min',
#   None,
#   None),
#  ('male',
#   1,
#   'Greasy Rider',
#   'self',
#   'Picture a cross-country road trip powered by vegetable oil in a 1981 Mercedes-Benz. Greasy Rider follows the two filmmakers, Joey Carey and JJ Beck, as they meet with fellow Greasecar drivers, friends, and critics.',
#   70.0,
#   None,
#   'movie',
#   '2006-10-14',
#   '48 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Absolute Power: The Making of Edison Force',
#   'self',
#   'A behind-the-scenes documentary on the making of the political thriller "Edison Force".',
#   55.0,
#   None,
#   'movie',
#   '2006-07-18',
#   None,
#   'Short',
#   None),
#  ('male',
#   1,
#   'The Reichen Show',
#   'self',
#   None,
#   41.0,
#   None,
#   'series',
#   '2005-11-11',
#   '60 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Ellen: The Ellen DeGeneres Show',
#   'self',
#   'A mix of celebrity interviews, musical performers, audience participation games, and segments spotlighting real people with extraordinary stories and talents.',
#   72.0,
#   None,
#   'series',
#   '2003-09-08',
#   '60 min',
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The 78th Annual Academy Awards',
#   'self',
#   'Films contending for the annual awards include Brokeback Mountain (2005), Capote (2005), Crash (2004), Good Night, and Good Luck. (2005) and Munich (2005).',
#   67.0,
#   None,
#   'movie',
#   '2006-03-05',
#   '214 min',
#   'Music',
#   None),
#  ('male',
#   1,
#   '60 Minutes',
#   'self',
#   'The classic long-running prime time TV investigative news magazine.',
#   75.0,
#   None,
#   'series',
#   '1968-09-24',
#   '60 min',
#   'Documentary, News',
#   None),
#  ('male',
#   1,
# ...
#   None),
#  ('male',
#   1,
#   'Getaway',
#   'self',
#   'The first season looked at only tourism in Australia, including resorts and locations, but by 1993 had expanded to look at international travel and tourism destinations.',
#   59.0,
#   None,
#   'series',
#   '1992-05-14',
#   '60 min',
#   None,
#   None),
#  ('male',
#   1,
#   'Out of Africa: Heroes and Icons',
#   'self',
#   None,
#   59.0,
#   None,
#   'movie',
#   '2005-06-18',
#   '90 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Festival international de Cannes',
#   'self',
#   None,
#   None,
#   None,
#   'series',
#   None,
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'La noche con Fuentes y Cía',
#   'self',
#   None,
#   40.0,
#   None,
#   'series',
#   '2001-09-30',
#   '60 min',
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Challenge of Freedom',
#   'self',
#   None,
#   69.0,
#   None,
#   'movie',
#   '2005-02-01',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The 77th Annual Academy Awards',
#   'self',
#   'Films nominated for the annual awards include The Aviator (2004), Finding Neverland (2004), Million Dollar Baby (2004), Ray (2004) and Sideways (2004).',
#   60.0,
#   None,
#   'movie',
#   '2005-02-27',
#   '194 min',
#   'Music',
#   None),
#  ('male',
#   1,
#   '11th Annual Screen Actors Guild Awards',
#   'self',
#   'The Screen Actors Guild Awards are where the actors call the shots. With 13 categories, the voting is done all by actors. With both television and film categories, the best performances of the year are recognized.',
#   63.0,
#   None,
#   'movie',
#   '2005-02-05',
#   '120 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'March of the Penguins',
#   'self',
#   'In the Antarctic, every March since the beginning of time, the quest begins to find the perfect mate and start a family.',
#   76.0,
#   77100000.0,
#   'movie',
#   '2005-07-22',
#   '80 min',
#   'Documentary, Family',
#   None),
#  ('male',
#   1,
#   'Tsunami Aid: A Concert of Hope',
#   'self',
#   None,
#   57.0,
#   None,
#   'movie',
#   '2005-01-15',
#   '120 min',
#   'Music',
#   None),
#  ('male',
#   1,
#   'Inside Dish with Rachael Ray',
#   'self',
#   None,
#   39.0,
#   None,
#   'series',
#   '2004-11-05',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Genius: A Night for Ray Charles',
#   'self',
#   None,
#   62.0,
#   None,
#   'movie',
#   '2004-10-22',
#   '60 min',
#   'Music',
#   None),
#  ('male',
#   1,
#   'The Shawshank Redemption: Behind the Scenes',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '2004-09-20',
#   '9 min',
#   'Short',
#   None),
#  ('male',
#   1,
#   'Survivors of the Shoah: Visual History Foundation',
#   'self',
#   '11 minute introduction to the Visual History Foundation and the work being done to document and archive the first-person histories of the remaining Survivors of the Shoah.',
#   63.0,
#   None,
#   'movie',
#   '2004-03-09',
#   '11 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Tinseltown TV',
#   'self',
#   'Five camera crews are in action all week bringing audiences the best in film premieres, behind the scenes exclusives, music events, fashion shows and celebrity parties across the globe.',
#   83.0,
#   None,
#   'series',
#   '2003-08-02',
#   '60 min',
#   'Music, News',
#   None),
#  ('male',
#   1,
#   'The Living Blues',
#   'self',
#   'Discussion of the history and interpretation of the musical style known as the "delta blues". Documentary features blues artists discussing the background and growth of the blues, and its ...',
#   60.0,
#   None,
#   'movie',
#   None,
#   '120 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The Art of Romare Bearden',
#   'self',
#   '"The Art of Romare Bearden" was produced by the National Gallery of Art on the occasion of the exhibition of the same title. The film is narrated by Morgan Freeman with readings by Danny ...',
#   None,
#   None,
#   'movie',
#   '2003-09-01',
#   '35 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'A Tale of Two Schools',
#   'self',
#   'A look at the efforts to teach reading to elementary school students in Mississippi and Texas.',
#   63.0,
#   None,
#   'movie',
#   '2003-09-01',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'God kveld Norge',
#   'self',
#   'Norwegian program with entertainment news from home and abroad.',
#   44.0,
#   None,
#   'series',
#   None,
#   '30 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'America Beyond the Color Line with Henry Louis Gates Jr.',
#   'self',
#   'Through numerous personal interviews, professor Henry Louis Gates Jr. examines the past, present, and future of black/white race relations in the USA.',
#   75.0,
#   None,
#   'series',
#   None,
#   '225 min',
#   'Documentary, History',
#   None),
#  ('male',
#   1,
#   "All on Accounta Pullin' a Trigger",
#   'self',
#   None,
#   65.0,
#   None,
#   'movie',
#   '2002-09-24',
#   '22 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Revealed with Jules Asner',
#   'self',
#   None,
#   55.0,
#   None,
#   'series',
#   '2003-09-08',
#   '60 min',
#   None,
#   None),
#  ('male',
#   1,
#   'Leute heute',
#   'self',
#   None,
#   43.0,
#   None,
#   'series',
#   None,
#   None,
#   'Documentary, Family, Romance',
#   None),
#  ('male',
#   1,
#   'Independence Day 2001',
#   'self',
#   None,
#   58.0,
#   None,
#   'movie',
#   None,
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   "The Making of 'Along Came a Spider'",
#   'self',
#   None,
#   57.0,
#   None,
#   'movie',
#   '2001-09-25',
#   '14 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'The Panel',
#   'self',
#   None,
#   65.0,
#   None,
#   'series',
#   '1998-02-18',
#   '90 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   "AFI's 100 Years... 100 Thrills: America's Most Heart-Pounding Movies",
#   'self',
#   'A look at the 100 most thrilling films in over 100 years of American cinema.',
#   70.0,
#   None,
#   'movie',
#   '2001-06-12',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The 73rd Annual Academy Awards',
#   'self',
#   None,
#   60.0,
#   None,
#   'movie',
#   '2001-03-25',
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   'Lux',
#   'self',
#   None,
#   None,
#   None,
#   'series',
#   None,
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'The Kennedy Center Honors: A Celebration of the Performing Arts',
#   'self',
#   None,
#   64.0,
#   None,
#   'movie',
#   '2000-12-27',
#   None,
#   'Documentary, Music',
#   None),
#  ('male',
#   1,
#   'The Chris Rock Show',
#   'self',
#   "America's funniest comedian in a less than PC setting. It's hilarious !",
#   68.0,
#   None,
#   'series',
#   '1997-02-07',
#   None,
#   'Comedy, Music, Talk-Show',
#   None),
#  ('male',
#   1,
#   "AFI's 100 Years... 100 Laughs: America's Funniest Movies",
#   'self',
#   None,
#   64.0,
#   None,
#   'movie',
#   '2000-06-13',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The 57th Annual Golden Globe Awards',
#   'self',
#   None,
#   45.0,
#   None,
#   'movie',
#   '2000-01-01',
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   "AFI's 100 Years... 100 Stars: America's Greatest Screen Legends",
#   'self',
#   "The spectacular CBS special! Shirley Temple Black hosts the festivities as 50 of today's top stars count down the 50 greatest screen legends of all time. Features Clint Eastwood, Jack Lemmon, Shirley MacLaine, Kevin Spacey and many others.",
#   56.0,
#   None,
#   'movie',
#   '1999-06-15',
#   '135 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   '30th NAACP Image Awards',
#   'self',
#   None,
#   75.0,
#   None,
#   'movie',
#   '1999-03-04',
#   '120 min',
#   'Family',
#   None),
#  ('male',
#   1,
#   'Scandalize My Name: Stories from the Blacklist',
#   'self',
#   'A documentary look at the confluence of the Red scare, McCarthyism, and blacklists with the post-war activism by African Americans seeking more and better roles on radio, television, and ...',
#   79.0,
#   None,
#   'movie',
#   None,
#   '54 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   '29th NAACP Image Awards',
#   'self',
#   None,
#   51.0,
#   None,
#   'movie',
#   None,
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   'The Long Way Home',
#   'self',
#   'The story of the post World War II Jewish refugee situation from liberation to the establishment of the modern state of Israel.',
#   75.0,
#   None,
#   'movie',
#   '1997-09-19',
#   '120 min',
#   'Documentary, History, War',
#   None),
#  ('male',
#   1,
#   '3rd Annual Screen Actors Guild Awards',
#   'self',
#   None,
#   63.0,
#   None,
#   'movie',
#   '1997-02-22',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   "Kennedy Center's 25th Anniversary",
#   'self',
#   None,
#   64.0,
#   None,
#   'movie',
#   '1996-08-18',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Cosmic Voyage',
#   'self',
#   'Where do we fit in with the universe? This film seeks to explore our place among the ever-expanding universe.',
#   76.0,
#   None,
#   'movie',
#   '1996-08-09',
#   '36 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'Inside the White House',
#   'self',
#   'A revealing look inside the most famous house in America.',
#   67.0,
#   None,
#   'movie',
#   None,
#   '90 min',
#   'Documentary, Biography, History',
#   None),
#  ('male',
#   1,
#   'The Promised Land',
#   'self',
#   'This program documents the migration of rural Southern blacks from the segregated South to Chicago. Cultural and political gains become offset by overcrowding and increasing ghettoization, ...',
#   75.0,
#   None,
#   'series',
#   '1995-02-12',
#   None,
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'A Century of Cinema',
#   'self',
#   None,
#   56.0,
#   None,
#   'movie',
#   None,
#   '72 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The 51st Annual Golden Globe Awards',
#   'self',
#   None,
#   65.0,
#   None,
#   'movie',
#   '1994-01-22',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   '25th NAACP Image Awards',
#   'self',
#   None,
#   55.0,
#   None,
#   'movie',
#   '1993-01-25',
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   "Eastwood & Co.: Making 'Unforgiven'",
#   'self',
#   None,
#   70.0,
#   None,
#   'movie',
#   '2002-09-24',
#   '24 min',
#   'Documentary, Short',
#   None),
#  ('male',
#   1,
#   'The Arsenio Hall Show',
#   'self',
#   'Arsenio Hall hosts this hip, late-night talk show.',
#   64.0,
#   None,
#   'series',
#   '1989-01-03',
#   '60 min',
#   'Comedy, Family, Music',
#   None),
#  ('male',
#   1,
#   'Neglect Not the Children',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '1991-09-09',
#   '57 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'The 43th Annual Writers Guild Awards',
#   'self',
#   None,
#   None,
#   None,
#   'movie',
#   '1991-03-20',
#   None,
#   'Reality-TV',
#   None),
#  ('male',
#   1,
#   "The 17th Annual People's Choice Awards",
#   'self',
#   None,
#   63.0,
#   None,
#   'movie',
#   None,
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'The 48th Annual Golden Globe Awards',
#   'self',
#   "Golden Globe Award - American award awarded by the Hollywood association of the foreign press from 1944 for works in movies and television's pictures.",
#   74.0,
#   None,
#   'movie',
#   '1991-01-19',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'The 44th Annual Tony Awards',
#   'self',
#   None,
#   72.0,
#   None,
#   'movie',
#   '1990-06-03',
#   '120 min',
#   'Musical',
#   None),
#  ('male',
#   1,
#   'The 62nd Annual Academy Awards',
#   'self',
#   None,
#   59.0,
#   None,
#   'movie',
#   '1990-03-26',
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   'The 47th Annual Golden Globe Awards',
#   'self',
#   None,
#   65.0,
#   None,
#   'movie',
#   '1990-01-20',
#   '120 min',
#   None,
#   None),
#  ('male',
#   1,
#   'The 60th Annual Academy Awards',
#   'self',
#   None,
#   46.0,
#   None,
#   'movie',
#   '1988-04-11',
#   None,
#   None,
#   None),
#  ('male',
#   1,
#   'Working in the Theatre',
#   'self',
#   'Bringing together performers, directors, playwrights, designers, choreographers, producers and behind-the-scenes personnel from the American and international theatre, the program offers a ...',
#   65.0,
#   None,
#   'series',
#   '1979-09-02',
#   '60 min',
#   'Documentary, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Out to Lunch',
#   'self',
#   'The Muppets and the casts of "The Electric Company" and "Sesame Street" take over the ABC Nightly News when the newsroom staff takes a lunch break.',
#   72.0,
#   None,
#   'movie',
#   '1974-12-10',
#   '60 min',
#   'Comedy, Family',
#   None),
#  ('male',
#   1,
#   'The 22nd Annual Tony Awards',
#   'self',
#   None,
#   72.0,
#   None,
#   'movie',
#   '1968-04-21',
#   None,
#   'Family',
#   None),
#  ('male',
#   1,
#   'Good Morning Britain',
#   'archive_footage',
#   'The weekday news on ITV that the whole nation wakes up to.',
#   43.0,
#   None,
#   'series',
#   '2014-04-28',
#   '150 min',
#   'News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Tucker Carlson Tonight',
#   'archive_footage',
#   'Powerful analysis and spirited debates with guests from across the political and cultural spectrum.',
#   76.0,
#   None,
#   'series',
#   '2016-11-14',
#   '60 min',
#   'News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Celebrity Page',
#   'archive_footage',
#   'A look at the top stories in entertainment and celebrity news.',
#   53.0,
#   None,
#   'series',
#   '2013-09-09',
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'Access Hollywood',
#   'archive_footage',
#   'Celebrity information, hollywood gossip, and other news from the world of entertainment.',
#   35.0,
#   None,
#   'series',
#   '1996-09-01',
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   'Gruen XL',
#   'archive_footage',
#   "The show that lifts the lid on advertising, spin and marketing. Join host Wil Anderson, stalwarts Todd Sampson and Russel Howcroft and other advertising industry experts to unpick the ways we're all bought and sold.",
#   None,
#   None,
#   'series',
#   '2015-09-16',
#   None,
#   'Comedy, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Inside Edition',
#   'archive_footage',
#   'Along with Hard Copy (1989) and A Current Affair (1986), this show was one of the early alternative news shows to be carried nationwide in the US. Primary stories usually focused on sex ...',
#   39.0,
#   None,
#   'series',
#   None,
#   '30 min',
#   'Documentary, News',
#   None),
#  ('male',
#   1,
#   "The Second Annual 'On Cinema' Oscar Special",
#   'archive_footage',
#   None,
#   86.0,
#   None,
#   'movie',
#   '2014-03-02',
#   '119 min',
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'The Fire Rises: The Creation and Impact of the Dark Knight Trilogy',
#   'archive_footage',
#   'Documentary about the Dark Knight Trilogy.',
#   85.0,
#   None,
#   'movie',
#   '2013-09-24',
#   '77 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Movie Guide',
#   'archive_footage',
#   None,
#   82.0,
#   None,
#   'series',
#   '2013-04-11',
#   '6 min',
#   'Action, News, Talk-Show',
#   None),
#  ('male',
#   1,
#   "Betty White's 2nd Annual 90th Birthday",
#   'archive_footage',
#   None,
#   78.0,
#   None,
#   'movie',
#   '2013-02-05',
#   '60 min',
#   'Comedy',
#   None),
#  ('male',
#   1,
#   'The Descendants',
#   'archive_footage',
#   'A land baron tries to reconnect with his two daughters after his wife is seriously injured in a boating accident.',
#   73.0,
#   78500000.0,
#   'movie',
#   '2011-12-09',
#   '115 min',
#   'Comedy, Drama',
#   None),
#  ('male',
#   1,
#   'I Am',
#   'archive_footage',
#   "Director Tom Shadyac speaks with intellectual and spiritual leaders about what's wrong with our world and how we can improve both it and the way we live in it.",
#   76.0,
#   1570251.0,
#   'movie',
#   '2011-02-01',
#   '78 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   'Never Sleep Again: The Elm Street Legacy',
#   'archive_footage',
#   'Explore the origins of "dream demon" Freddy Krueger in this award-winning documentary that takes you behind the scenes of the most frightening and imaginative horror franchise in motion picture history!',
#   87.0,
#   None,
#   'movie',
#   '2010-05-04',
#   '240 min',
#   'Documentary, Horror',
#   None),
#  ('male',
#   1,
#   'Almost Famous III',
#   'archive_footage',
#   None,
#   73.0,
#   None,
#   'movie',
#   '2010-01-02',
#   '60 min',
#   'Documentary',
#   None),
#  ('male',
#   1,
#   "The O'Reilly Factor",
#   'archive_footage',
#   'Fox News Channel news and talk show.',
#   35.0,
#   None,
#   'series',
#   '1996-10-07',
#   '60 min',
#   'News, Talk-Show',
#   None),
#  ('male',
#   1,
#   'Today Tonight',
#   'archive_footage',
#   None,
#   14.0,
#   None,
#   'series',
#   None,
#   '30 min',
#   'News',
#   None),
#  ('male',
#   1,
#   '101 Favorite Stars Way Back When',
#   'archive_footage',
#   None,
#   58.0,
#   None,
#   'series',
#   '2007-01-22',
#   '1 h',
#   'Biography',
#   None),
#  ('male',
#   1,
#   'The Another World Reunion',
#   'archive_footage',
#   None,
#   80.0,
#   None,
#   'movie',
#   '2003-10-23',
#   None,
#   'Talk-Show',
#   None),
#  ('male',
#   1,
#   'Biography',
#   'archive_footage',
#   'The life stories of various historical figures and celebrities are told.',
#   79.0,
#   None,
#   'series',
#   '1987-04-06',
#   '60 min',
#   'Documentary, Biography',
#   None)]

# %%
dictlist = []
movies = []

#Append data      
actordict = {}
actordictinner = {}


for this in data:
    moviesdict = {}
    moviesdict["title"] = (this[2])
    moviesdict["released"] = (this[8])
    moviesdict["credit"] = (this[3])
    moviesdict["runtime"] = (this[9])
    moviesdict["genre(s)"] = (this[10])
    moviesdict["plot"] = (this[4])
    moviesdict["imdb_rating"] = (this[5])
    moviesdict["rt_rating"] = (this[11])
    moviesdict["box_office"] = (this[6])
    moviesdict["type"] = (this[7])
    movies.append(moviesdict)    
    
actordict[selection] = actordictinner
actordictinner["gender"] = data[0][0]
actordictinner["rank"] = data[0][1]
actordictinner["movies"] = movies

dictlist.append(actordict)
 
actordict
# Out:
# {'Morgan Freeman': {'gender': 'male',
#   'rank': 1,
#   'movies': [{'title': 'The Comeback Trail',
#     'released': None,
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Action',
#     'plot': 'Two movie producers who owe money to the mob, set up their aging movie star for an insurance scam to try and save themselves but winding up getting more than they ever imagined.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Angel Has Fallen',
#     'released': '2019-08-23',
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Action, Drama, Thriller',
#     'plot': 'Secret Service Agent Mike Banning is framed for the attempted assassination of the President and must evade his own agency and the FBI as he tries to uncover the real threat.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Nutcracker and the Four Realms',
#     'released': '2018-11-02',
#     'credit': 'actor',
#     'runtime': '99 min',
#     'genre(s)': 'Adventure, Family, Fantasy',
#     'plot': 'A young girl is transported into a magical world of gingerbread soldiers and an army of mice.',
#     'imdb_rating': 55.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Just Getting Started',
#     'released': '2017-12-08',
#     'credit': 'actor',
#     'runtime': '91 min',
#     'genre(s)': 'Action, Comedy',
#     'plot': 'A two-hander action comedy in the vein of Midnight Run (1988), about an ex-F.B.I. Agent (Tommy Lee Jones) and an ex-mob lawyer in the Witness Protection Program (Morgan Freeman) having to put aside their petty rivalry on the golf course to fend off a mob hit.',
#     'imdb_rating': 44.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Going in Style',
#     'released': '2017-04-07',
#     'credit': 'actor',
#     'runtime': '96 min',
#     'genre(s)': 'Comedy, Crime',
#     'plot': 'Desperate to pay the bills and come through for their loved ones, three lifelong pals risk it all by embarking on a daring bid to knock off the very bank that absconded with their money.',
#     'imdb_rating': 66.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Now You See Me 2',
#     'released': '2016-06-10',
#     'credit': 'actor',
#     'runtime': '129 min',
#     'genre(s)': 'Action, Adventure, Comedy, Crime, Mystery, Thriller',
#     'plot': 'The Four Horsemen resurface, and are forcibly recruited by a tech genius to pull off their most impossible heist yet.',
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': 65030563.0,
#     'type': 'movie'},
#    {'title': 'Momentum',
#     'released': '2015-10-16',
#     'credit': 'actor',
#     'runtime': '96 min',
#     'genre(s)': 'Action, Crime, Thriller',
#     'plot': 'Alex, a mysterious thief, is pulled in by her former partner for one last heist. She quickly finds it was never just about the diamonds. A brutal murder sparks a cat and mouse chase between...',
#     'imdb_rating': 55.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Last Knights',
#     'released': '2015-04-03',
#     'credit': 'actor',
#     'runtime': '115 min',
#     'genre(s)': 'Action, Adventure, Drama',
#     'plot': 'A fallen warrior rises against a corrupt and sadistic ruler to avenge his dishonored master.',
#     'imdb_rating': 62.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Dolphin Tale 2',
#     'released': '2014-09-12',
#     'credit': 'actor',
#     'runtime': '107 min',
#     'genre(s)': 'Drama, Family',
#     'plot': "The team of people who saved Winter's life reassemble in the wake of her surrogate mother's passing in order to find her a companion so she can remain at the Clearwater Marine Hospital.",
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Lucy',
#     'released': '2014-07-25',
#     'credit': 'actor',
#     'runtime': '89 min',
#     'genre(s)': 'Action, Sci-Fi, Thriller',
#     'plot': 'A woman, accidentally caught in a dark deal, turns the tables on her captors and transforms into a merciless warrior evolved beyond human logic.',
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': 108521370.0,
#     'type': 'movie'},
#    {'title': 'Transcendence',
#     'released': '2014-04-18',
#     'credit': 'actor',
#     'runtime': '119 min',
#     'genre(s)': 'Action, Drama, Sci-Fi, Thriller',
#     'plot': "A scientist's drive for artificial intelligence, takes on dangerous implications when his consciousness is uploaded into one such program.",
#     'imdb_rating': 63.0,
#     'rt_rating': None,
#     'box_office': 23014504.0,
#     'type': 'movie'},
#    {'title': 'Last Vegas',
#     'released': '2013-11-01',
#     'credit': 'actor',
#     'runtime': '105 min',
#     'genre(s)': 'Comedy, Drama',
#     'plot': 'Four friends take a break from their day-to-day lives to throw a bachelor party in Las Vegas for their last remaining single pal.',
#     'imdb_rating': 66.0,
#     'rt_rating': None,
#     'box_office': 51434214.0,
#     'type': 'movie'},
#    {'title': 'Oblivion',
#     'released': '2013-04-19',
#     'credit': 'actor',
#     'runtime': '124 min',
#     'genre(s)': 'Action, Adventure, Sci-Fi',
#     'plot': "A veteran assigned to extract Earth's remaining resources begins to question what he knows about his mission and himself.",
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': 89021735.0,
#     'type': 'movie'},
#    {'title': 'The Dark Knight Rises',
#     'released': '2012-07-20',
#     'credit': 'actor',
#     'runtime': '164 min',
#     'genre(s)': 'Action, Thriller',
#     'plot': "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City, now on the edge of total annihilation, from the brutal guerrilla terrorist Bane.",
#     'imdb_rating': 84.0,
#     'rt_rating': None,
#     'box_office': 448130642.0,
#     'type': 'movie'},
#    {'title': 'Dolphin Tale',
#     'released': '2011-09-23',
#     'credit': 'actor',
#     'runtime': '113 min',
#     'genre(s)': 'Drama, Family',
#     'plot': 'A story centered on the friendship between a boy and a dolphin whose tail was lost in a crab trap.',
#     'imdb_rating': 69.0,
#     'rt_rating': None,
#     'box_office': 65099999.0,
#     'type': 'movie'},
#    {'title': 'RED',
#     'released': '2010-10-15',
#     'credit': 'actor',
#     'runtime': '111 min',
#     'genre(s)': 'Action, Comedy, Crime, Thriller',
#     'plot': 'When his peaceful life is threatened by a high-tech assassin, former black-ops Agent Frank Moses (Bruce Willis) reassembles his old team in a last ditch effort to survive and uncover his assailants.',
#     'imdb_rating': 71.0,
#     'rt_rating': None,
#     'box_office': 88900000.0,
#     'type': 'movie'},
#    {'title': 'Invictus',
#     'released': '2009-12-11',
#     'credit': 'actor',
#     'runtime': '134 min',
#     'genre(s)': 'Biography, Drama, History, Sport',
#     'plot': 'Nelson Mandela, in his first term as the South African President, initiates a unique venture to unite the apartheid-torn land: enlist the national rugby team on a mission to win the 1995 Rugby World Cup.',
#     'imdb_rating': 73.0,
#     'rt_rating': None,
#     'box_office': 37431431.0,
#     'type': 'movie'},
#    {'title': 'Thick as Thieves',
#     'released': '2009-01-09',
#     'credit': 'actor',
#     'runtime': '104 min',
#     'genre(s)': 'Action, Crime, Thriller',
#     'plot': 'A veteran thief recruits a younger crook to help him pull off one final job in order to repay his debt to the Russian mob.',
#     'imdb_rating': 60.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Wanted',
#     'released': '2008-06-27',
#     'credit': 'actor',
#     'runtime': '110 min',
#     'genre(s)': 'Action, Crime, Fantasy, Thriller',
#     'plot': "A frustrated office worker learns that he is the son of a professional assassin and that he shares his father's superhuman killing abilities.",
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': 134294280.0,
#     'type': 'movie'},
#    {'title': 'The Bucket List',
#     'released': '2008-01-11',
#     'credit': 'actor',
#     'runtime': '97 min',
#     'genre(s)': 'Adventure, Comedy, Drama',
#     'plot': 'Two terminally ill men escape from a cancer ward and head off on a road trip with a wish list of to-dos before they die.',
#     'imdb_rating': 74.0,
#     'rt_rating': None,
#     'box_office': 93500000.0,
#     'type': 'movie'},
#    {'title': 'Gone Baby Gone',
#     'released': '2007-10-19',
#     'credit': 'actor',
#     'runtime': '114 min',
#     'genre(s)': 'Crime, Drama, Mystery, Thriller',
#     'plot': "Two Boston area detectives investigate a little girl's kidnapping, which ultimately turns into a crisis both professionally and personally.",
#     'imdb_rating': 77.0,
#     'rt_rating': None,
#     'box_office': 20300218.0,
#     'type': 'movie'},
#    {'title': 'The Contract',
#     'released': '2007-04-05',
#     'credit': 'actor',
#     'runtime': '96 min',
#     'genre(s)': 'Action, Crime, Drama, Thriller',
#     'plot': 'A father and his son attempt to bring in an assassin to the authorities, but his dangerous associates have other plans.',
#     'imdb_rating': 57.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Lucky Number Slevin',
#     'released': '2006-04-07',
#     'credit': 'actor',
#     'runtime': '110 min',
#     'genre(s)': 'Crime, Drama, Mystery, Thriller',
#     'plot': "A case of mistaken identity lands Slevin into the middle of a war being plotted by two of the city's most rival crime bosses: The Rabbi and The Boss. Slevin is under constant surveillance by relentless Detective Brikowski as well as the infamous assassin Goodkat and finds himself having to hatch his own ingenious plot to get them before they get him.",
#     'imdb_rating': 78.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Magnificent Desolation: Walking on the Moon 3D',
#     'released': '2005-09-23',
#     'credit': 'actor',
#     'runtime': '40 min',
#     'genre(s)': 'Documentary, Animation, Short',
#     'plot': 'This program strives to give the viewer an impression of what it is like to actually be on the moon. It provides a romantic, inspirational depiction of the Apollo astronauts travels on the ...',
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': 32533825.0,
#     'type': 'movie'},
#    {'title': 'Batman Begins',
#     'released': '2005-06-14',
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Action, Adventure, Crime, Fantasy, Sci-Fi, Thriller',
#     'plot': 'You play as Batman and unleash your terror into the heart of criminals battling against foes such as Dr. Crane/Scarecrow, Ras Al Ghul and Carmine Falcone.',
#     'imdb_rating': 82.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'game'},
#    {'title': 'Batman Begins',
#     'released': '2005-06-15',
#     'credit': 'actor',
#     'runtime': '140 min',
#     'genre(s)': 'Action, Adventure',
#     'plot': 'After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.',
#     'imdb_rating': 82.0,
#     'rt_rating': None,
#     'box_office': 204100000.0,
#     'type': 'movie'},
#    {'title': 'Unleashed',
#     'released': '2005-05-13',
#     'credit': 'actor',
#     'runtime': '103 min',
#     'genre(s)': 'Action, Crime, Drama, Thriller',
#     'plot': 'A man enslaved by the mob since childhood and raised into behaving like a human attack dog escapes his captors and attempts to start a new life.',
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': 24380112.0,
#     'type': 'movie'},
#    {'title': 'Million Dollar Baby',
#     'released': '2005-01-28',
#     'credit': 'actor',
#     'runtime': '132 min',
#     'genre(s)': 'Drama, Sport',
#     'plot': 'A determined woman works with a hardened boxing trainer to become a professional.',
#     'imdb_rating': 81.0,
#     'rt_rating': None,
#     'box_office': 100422786.0,
#     'type': 'movie'},
#    {'title': 'The Big Bounce',
#     'released': '2004-01-30',
#     'credit': 'actor',
#     'runtime': '88 min',
#     'genre(s)': 'Comedy, Crime',
#     'plot': "A small-time con artist and a Hawaiian real estate developer's mischevious, enterprising mistress team up for a potential $200,000 score.",
#     'imdb_rating': 49.0,
#     'rt_rating': None,
#     'box_office': 6331346.0,
#     'type': 'movie'},
#    {'title': 'Guilty by Association',
#     'released': '2003-07-22',
#     'credit': 'actor',
#     'runtime': '80 min',
#     'genre(s)': 'Action, Crime, Drama',
#     'plot': 'A man becomes guilty by association. Suspense ensues.',
#     'imdb_rating': 25.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Dreamcatcher',
#     'released': '2003-03-21',
#     'credit': 'actor',
#     'runtime': '134 min',
#     'genre(s)': 'Drama, Horror, Sci-Fi, Thriller',
#     'plot': "Friends on a camping trip discover that the town they're vacationing in is being plagued in an unusual fashion by parasitic aliens from outer space.",
#     'imdb_rating': 55.0,
#     'rt_rating': None,
#     'box_office': 33700000.0,
#     'type': 'movie'},
#    {'title': 'The Sum of All Fears',
#     'released': '2002-05-31',
#     'credit': 'actor',
#     'runtime': '124 min',
#     'genre(s)': 'Action, Drama, Thriller, War',
#     'plot': "C.I.A. analyst Jack Ryan must stop the plans of a Neo-Nazi faction that threatens to induce a catastrophic conflict between the United States and Russia's newly elected President by detonating a nuclear weapon at a football game in Baltimore, Maryland.",
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': 118471320.0,
#     'type': 'movie'},
#    {'title': 'Along Came a Spider',
#     'released': '2001-04-06',
#     'credit': 'actor',
#     'runtime': '104 min',
#     'genre(s)': 'Drama, Thriller',
#     'plot': "When a congressman's daughter under Secret Service protection is kidnapped from a private school, detective Alex Cross investigates the case even though he's recovering from the loss of his partner.",
#     'imdb_rating': 63.0,
#     'rt_rating': None,
#     'box_office': 73587034.0,
#     'type': 'movie'},
#    {'title': 'Nurse Betty',
#     'released': '2000-09-08',
#     'credit': 'actor',
#     'runtime': '110 min',
#     'genre(s)': 'Comedy, Crime, Drama, Romance',
#     'plot': "Comedy about a widow's post-traumatic obsession with a soap star.",
#     'imdb_rating': 62.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Deep Impact',
#     'released': '1998-05-08',
#     'credit': 'actor',
#     'runtime': '120 min',
#     'genre(s)': 'Action, Drama, Romance, Sci-Fi, Thriller',
#     'plot': 'Unless a comet can be destroyed before colliding with Earth, only those allowed into shelters will survive. Which people will survive?',
#     'imdb_rating': 62.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Amistad',
#     'released': '1997-12-25',
#     'credit': 'actor',
#     'runtime': '155 min',
#     'genre(s)': 'Drama, History',
#     'plot': 'In 1839, the revolt of Mende captives aboard a Spanish owned ship causes a major controversy in the United States when the ship is captured off the coast of Long Island. The courts must decide whether the Mende are slaves or legally free.',
#     'imdb_rating': 73.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Chain Reaction',
#     'released': '1996-08-02',
#     'credit': 'actor',
#     'runtime': '107 min',
#     'genre(s)': 'Action, Drama, Sci-Fi, Thriller',
#     'plot': 'Two researchers in a green alternative energy project are put on the run when they are framed for murder and treason.',
#     'imdb_rating': 56.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Se7en',
#     'released': '1995-09-22',
#     'credit': 'actor',
#     'runtime': '127 min',
#     'genre(s)': 'Crime, Drama, Mystery, Thriller',
#     'plot': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#     'imdb_rating': 86.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Shawshank Redemption',
#     'released': '1994-10-14',
#     'credit': 'actor',
#     'runtime': '142 min',
#     'genre(s)': 'Drama',
#     'plot': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#     'imdb_rating': 93.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Power of One',
#     'released': '1992-03-27',
#     'credit': 'actor',
#     'runtime': '127 min',
#     'genre(s)': 'Drama, Sport',
#     'plot': 'An English boy, living in Africa during World War II, through his boxing prowess, becomes a symbol of hope, in a time of war.',
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The True Story of Glory Continues',
#     'released': None,
#     'credit': 'actor',
#     'runtime': '46 min',
#     'genre(s)': 'Documentary, History, War',
#     'plot': None,
#     'imdb_rating': 57.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Robin Hood: Prince of Thieves',
#     'released': '1991-06-14',
#     'credit': 'actor',
#     'runtime': '143 min',
#     'genre(s)': 'Action, Adventure, Drama, Romance',
#     'plot': 'When Robin and his Moorish companion come to England and the tyranny of the Sheriff of Nottingham, he decides to fight back as an outlaw.',
#     'imdb_rating': 69.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Civil War',
#     'released': '1990-09-23',
#     'credit': 'actor',
#     'runtime': '680 min',
#     'genre(s)': 'Documentary, History, War',
#     'plot': 'A comprehensive survey of the American Civil War.',
#     'imdb_rating': 91.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Glory',
#     'released': '1990-02-16',
#     'credit': 'actor',
#     'runtime': '122 min',
#     'genre(s)': 'Biography, Drama, History, War',
#     'plot': "Robert Gould Shaw leads the U.S. Civil War's first all-black volunteer company, fighting prejudices from both his own Union Army, and the Confederates.",
#     'imdb_rating': 79.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Johnny Handsome',
#     'released': '1989-09-29',
#     'credit': 'actor',
#     'runtime': '94 min',
#     'genre(s)': 'Crime, Drama, Thriller',
#     'plot': 'After being double crossed and thrown in jail, a deformed gangster gets a new face and rehabilitation, but his desire for revenge looms.',
#     'imdb_rating': 61.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Clean and Sober',
#     'released': '1988-08-10',
#     'credit': 'actor',
#     'runtime': '124 min',
#     'genre(s)': 'Drama',
#     'plot': "A hustling drug addict checks himself into rehab to escape trouble with the law and realizes that it's exactly what he needs.",
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Fight for Life',
#     'released': '1987-03-23',
#     'credit': 'actor',
#     'runtime': '95 min',
#     'genre(s)': 'Drama',
#     'plot': 'Jerry Lewis plays an Ohio optometrist who has a six-year old daughter with epilepsy. He fights to get the FDA to approve a drug (at that time only available in England) for use in the U.S.',
#     'imdb_rating': 57.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Resting Place',
#     'released': '1986-04-27',
#     'credit': 'actor',
#     'runtime': '100 min',
#     'genre(s)': 'Drama',
#     'plot': "The mysterious death of an army officer comes under investigation by Major Kendall Laird as the young soldier's parents seek an honorable burial place, out of respect for their son. The ...",
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Twilight Zone',
#     'released': '1985-09-27',
#     'credit': 'actor',
#     'runtime': '45 min',
#     'genre(s)': 'Sci-Fi, Fantasy, Mystery, Thriller, Horror',
#     'plot': 'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#     'imdb_rating': 78.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'That Was Then... This Is Now',
#     'released': '1985-11-08',
#     'credit': 'actor',
#     'runtime': '102 min',
#     'genre(s)': 'Crime, Drama',
#     'plot': 'Two juvenile delinquents find themselves growing apart, for one is growing up, and the other is staying young and reckless.',
#     'imdb_rating': 62.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Atlanta Child Murders',
#     'released': '1985-02-10',
#     'credit': 'actor',
#     'runtime': '245 min',
#     'genre(s)': 'Crime, Drama, Mystery',
#     'plot': 'The city of Atlanta, Georgia, is terrorized by a rash of child murders occurring in its black community. When a black photographer is arrested for the crimes, controversy erupts over ...',
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Harry & Son',
#     'released': '1984-03-02',
#     'credit': 'actor',
#     'runtime': '120 min',
#     'genre(s)': 'Drama',
#     'plot': 'Harry Keach has been widowed for two years and works as a demolition crane operator on a demolition crew.',
#     'imdb_rating': 58.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Death of a Prophet',
#     'released': '2017-10-27',
#     'credit': 'actor',
#     'runtime': '60 min',
#     'genre(s)': 'Drama, History',
#     'plot': 'After breaking ties with the Nation of Islam, Malcolm X became a man marked for death...and it was just a matter of time before his enemies closed in. Despite death threats and intimidation...',
#     'imdb_rating': 49.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Ryan's Hope",
#     'released': '1975-07-07',
#     'credit': 'actor',
#     'runtime': '30 min',
#     'genre(s)': 'Drama',
#     'plot': "Set in Riverside on the upper West Side of Manhattan, Ryan's Hope centered mostly on the working class Ryans, an Irish-American family headed by Maeve and Johnny Ryan. They owned Ryan's Bar...",
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Eyewitness',
#     'released': '1981-02-13',
#     'credit': 'actor',
#     'runtime': '103 min',
#     'genre(s)': 'Crime, Drama, Mystery, Romance, Thriller',
#     'plot': 'Eccentric Vietnam War vet turned janitor claims to have witnessed a murder of a man tied to international political underground in order to get the attention of a TV reporter he has a huge crush on. The cops suspect his loser best friend.',
#     'imdb_rating': 60.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Attica',
#     'released': '1980-03-02',
#     'credit': 'actor',
#     'runtime': '97 min',
#     'genre(s)': 'Drama',
#     'plot': 'The behind the scenes of the 1971 prisoners revolt at the Attica prison.',
#     'imdb_rating': 66.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Julius Caesar',
#     'released': None,
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Drama, History',
#     'plot': 'The growing ambition of Julius Caesar is a source of major concern to his close friend Brutus. Cassius persuades him to participate in his plot to assassinate Caesar but they have both sorely underestimated Mark Antony.',
#     'imdb_rating': 57.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Visions',
#     'released': '1976-10-21',
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Drama',
#     'plot': 'Weekly anthology series of original dramas, often with period settings.',
#     'imdb_rating': 59.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Electric Company',
#     'released': '1971-10-25',
#     'credit': 'actor',
#     'runtime': '28 min',
#     'genre(s)': 'Family, Comedy',
#     'plot': 'A comedy variety show that teaches basic phonetic and grammar concepts using live-action sketches, cartoons, songs, and Spider-Man episodes.',
#     'imdb_rating': 82.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': "Who Says I Can't Ride a Rainbow!",
#     'released': '1971-11-18',
#     'credit': 'actor',
#     'runtime': '85 min',
#     'genre(s)': 'Family, Drama',
#     'plot': 'Barney (Jack Klugman) owns the last working farm in Manhattan. For various reasons, city officials have decided to close it down. A special event is planned to raise awareness and money to ...',
#     'imdb_rating': 60.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'New York Television Theatre',
#     'released': None,
#     'credit': 'actor',
#     'runtime': None,
#     'genre(s)': 'Comedy, Drama',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'A Man Called Adam',
#     'released': '1967-12-07',
#     'credit': 'actor',
#     'runtime': '99 min',
#     'genre(s)': 'Drama, Music',
#     'plot': 'A famous jazz trumpeter finds himself unable to cope with the problems of everyday life.',
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Madam Secretary',
#     'released': '2014-09-21',
#     'credit': 'producer',
#     'runtime': '45 min',
#     'genre(s)': 'Drama',
#     'plot': 'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#     'imdb_rating': 76.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Through the Wormhole',
#     'released': '2010-06-09',
#     'credit': 'producer',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#     'imdb_rating': 86.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': '5 Flights Up',
#     'released': '2015-05-08',
#     'credit': 'producer',
#     'runtime': '88 min',
#     'genre(s)': 'Comedy, Drama',
#     'plot': "A long-time married couple who've spent their lives together in the same New York apartment become overwhelmed by personal and real estate-related issues when they plan to move away.",
#     'imdb_rating': 62.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Stem Cell Universe with Stephen Hawking',
#     'released': '2014-02-03',
#     'credit': 'producer',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Led by a pioneer in the science world, Stephen Hawking, this special takes us on a journey which delves into the subjects of stem cells both embryonic and adult to explore what these ...',
#     'imdb_rating': 82.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '30 for 30',
#     'released': '2009-10-06',
#     'credit': 'producer',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary, Biography, History, Sport',
#     'plot': "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#     'imdb_rating': 88.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Maiden Heist',
#     'released': '2010-07-08',
#     'credit': 'producer',
#     'runtime': '90 min',
#     'genre(s)': 'Comedy, Crime',
#     'plot': 'A comedy centered on three museum security guards who devise a plan to steal back the artworks to which they have become attached after they are transferred to another museum.',
#     'imdb_rating': 61.0,
#     'rt_rating': None,
#     'box_office': 481378.0,
#     'type': 'movie'},
#    {'title': 'Levity',
#     'released': '2003-08-29',
#     'credit': 'producer',
#     'runtime': '100 min',
#     'genre(s)': 'Crime, Drama',
#     'plot': 'After two decades in prison for murder, a man is released on parole and returns to his hometown seeking redemption.',
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Under Suspicion',
#     'released': '2000-11-15',
#     'credit': 'producer',
#     'runtime': '110 min',
#     'genre(s)': 'Crime, Drama, Thriller',
#     'plot': 'A lawyer is asked to come to the police station to clear up a few loose ends in his witness report of a foul murder. This will only take ten minutes, they say, but it turns out to be one ...',
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Going in Style',
#     'released': '2017-04-07',
#     'credit': 'soundtrack',
#     'runtime': '96 min',
#     'genre(s)': 'Comedy, Crime',
#     'plot': 'Desperate to pay the bills and come through for their loved ones, three lifelong pals risk it all by embarking on a daring bid to knock off the very bank that absconded with their money.',
#     'imdb_rating': 66.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '10 Items or Less',
#     'released': '2007-02-08',
#     'credit': 'soundtrack',
#     'runtime': '82 min',
#     'genre(s)': 'Comedy, Drama',
#     'plot': 'An actor (Freeman) prepping for an upcoming role meets a quirky grocery clerk (Vega), and the pair hit the road to show one another their respective worlds.',
#     'imdb_rating': 66.0,
#     'rt_rating': None,
#     'box_office': 69265.0,
#     'type': 'movie'},
#    {'title': 'Madam Secretary',
#     'released': '2014-09-21',
#     'credit': 'director',
#     'runtime': '45 min',
#     'genre(s)': 'Drama',
#     'plot': 'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#     'imdb_rating': 76.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Raise My Hands',
#     'released': None,
#     'credit': 'miscellaneous',
#     'runtime': '9 min',
#     'genre(s)': 'Documentary, Short, Biography',
#     'plot': 'A tribute to a man who stood against apartheid, and changed the world.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Now You See Me 2: Bringing Magic to Life',
#     'released': '2016-09-06',
#     'credit': 'thanks',
#     'runtime': '16 min',
#     'genre(s)': 'Documentary, Short',
#     'plot': 'A philosophical musings about the wonder of magic.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Last White Knight',
#     'released': '2013-07-31',
#     'credit': 'thanks',
#     'runtime': '78 min',
#     'genre(s)': 'Documentary, Biography, History',
#     'plot': 'In 1965, 21-year-old Torontonian, Paul Saltzman drove to Mississippi, volunteering as a civil rights worker with the Student Non-Violent Coordinating Committee. He was arrested, spending 10...',
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Biography: Morgan Freeman',
#     'released': None,
#     'credit': 'thanks',
#     'runtime': None,
#     'genre(s)': 'Biography',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Strength and Honour',
#     'released': '2007-11-30',
#     'credit': 'thanks',
#     'runtime': '95 min',
#     'genre(s)': 'Action, Drama',
#     'plot': "A single father decides to break his dying wife's last wish to not box again in order to save his young son from certain death.",
#     'imdb_rating': 60.0,
#     'rt_rating': None,
#     'box_office': 51933.0,
#     'type': 'movie'},
#    {'title': 'Bobby Rush: Live at Ground Zero',
#     'released': '2007-04-03',
#     'credit': 'thanks',
#     'runtime': '74 min',
#     'genre(s)': 'Music',
#     'plot': 'Bobby Rush, a fifty-year veteran of the blues "chitlin\' circuit" performs a set at the Ground Zero Blues Club in Clarksdale, Mississippi.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Scandalize My Name: Stories from the Blacklist',
#     'released': None,
#     'credit': 'thanks',
#     'runtime': '54 min',
#     'genre(s)': 'Documentary',
#     'plot': 'A documentary look at the confluence of the Red scare, McCarthyism, and blacklists with the post-war activism by African Americans seeking more and better roles on radio, television, and ...',
#     'imdb_rating': 79.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Panama Canal in 3D a Land Divided a World United',
#     'released': None,
#     'credit': 'self',
#     'runtime': '45 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Through the magic of 3D and IMAX cameras, audiences everywhere can take a mind-blowing trip through one of the seven wonders of the modern world in PANAMA CANAL 3D: A LAND DIVIDED A WORLD ...',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Jimmy Kimmel Live!',
#     'released': '2003-01-26',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Music, Talk-Show',
#     'plot': 'Jimmy Kimmel interviews celebrities.',
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The 24th Annual Screen Actors Guild Awards',
#     'released': '2018-01-21',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 85.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Golden Globes 75th Anniversary Special',
#     'released': '2017-12-13',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'Documentary, Comedy, Reality-TV',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Late Late Show with James Corden',
#     'released': '2015-03-23',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Talk-Show',
#     'plot': 'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#     'imdb_rating': 63.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Dr. Oz Show',
#     'released': '2009-09-14',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Talk-Show',
#     'plot': 'Dr. Oz delivers health tips you may have received from your doctor in the form of a talk show.',
#     'imdb_rating': 47.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'CBS This Morning',
#     'released': '2012-01-09',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'News',
#     'plot': 'A mix of news, features and interviews with notable figures in politics, business and entertainment.',
#     'imdb_rating': 57.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Entertainment Tonight',
#     'released': '1981-09-14',
#     'credit': 'self',
#     'runtime': '30 min',
#     'genre(s)': 'News',
#     'plot': '"Entertainment Tonight" is the #1 syndicated entertainment newsmagazine in the world. Launched in 1981, ET is anchored by Mary Hart and Bob Goen. Primary substitute anchors are Jann Carl ...',
#     'imdb_rating': 37.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Celebrity Page',
#     'released': '2013-09-09',
#     'credit': 'self',
#     'runtime': '30 min',
#     'genre(s)': 'News',
#     'plot': 'A look at the top stories in entertainment and celebrity news.',
#     'imdb_rating': 53.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Through the Wormhole',
#     'released': '2010-06-09',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#     'imdb_rating': 86.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The View',
#     'released': '1997-08-11',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Talk-Show',
#     'plot': 'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#     'imdb_rating': 28.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Late Night with Seth Meyers',
#     'released': '2014-02-24',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Talk-Show',
#     'plot': 'Seth Meyers hosts a late-night talk show.',
#     'imdb_rating': 60.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Tonight Show Starring Jimmy Fallon',
#     'released': '2014-02-17',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Music, Talk-Show',
#     'plot': 'Jimmy Fallon hosts the Tonight Show and interviews celebrities, plays games with them and has a musical or comedic guest perform.',
#     'imdb_rating': 74.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Age of Spin: Dave Chappelle Live at the Hollywood Palladium',
#     'released': '2017-03-21',
#     'credit': 'self',
#     'runtime': '67 min',
#     'genre(s)': 'Documentary, Comedy',
#     'plot': 'Dave Chappelle gives his usual skewed insight into the topics of race, technology, OJ Simpson, and more in a stand up special filmed in Hollywood.',
#     'imdb_rating': 80.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'National Endowment for the Arts: United States of Arts',
#     'released': '2015-09-25',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Documentary, Short',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Live! with Kelly',
#     'released': None,
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Talk-Show',
#     'plot': 'This popular and long-running morning talk show owes much of its success to the chemistry between its two hosts, Regis Philbin and Kelly Ripa. Although the format is not significantly ...',
#     'imdb_rating': 48.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Now You See Me 2: Bringing Magic to Life',
#     'released': '2016-09-06',
#     'credit': 'self',
#     'runtime': '16 min',
#     'genre(s)': 'Documentary, Short',
#     'plot': 'A philosophical musings about the wonder of magic.',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Good Morning America',
#     'released': '1975-01-06',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'News, Talk-Show',
#     'plot': 'ABC\'s "Good Morning America" presents the News and Information Source of the day\'s topics and journalism. The 1st Co-Host Team of David Hartman & Nancy Dussault, 2nd was Sandy Hill, 3rd was ...',
#     'imdb_rating': 50.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': "The Making of 'London Has Fallen'",
#     'released': '2016-06-14',
#     'credit': 'self',
#     'runtime': '13 min',
#     'genre(s)': 'Documentary, Short',
#     'plot': "Making a sequel after the original hit, the new movie's direction and plot, characters and their actions, performances, Babak Najafi's direction, the movie's impressive cast, the logistics ...",
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The C Word',
#     'released': '2016-11-25',
#     'credit': 'self',
#     'runtime': '89 min',
#     'genre(s)': 'Documentary',
#     'plot': 'A personal, important, surprising, and funny documentary about the industries of death that give us cancer, and the unheralded science of prevention.',
#     'imdb_rating': 74.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Oscars',
#     'released': '2016-02-28',
#     'credit': 'self',
#     'runtime': '217 min',
#     'genre(s)': 'Comedy, Music',
#     'plot': 'The 88th Academy Awards ceremony honors achievement in film in 2015.',
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '73rd Golden Globe Awards',
#     'released': '2016-01-10',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': "The Hollywood Foreign Press Association's 73rd annual event honoring excellence in film and television, hosted by Ricky Gervais.",
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Oprah's Master Class: Belief Special",
#     'released': '2015-10-11',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 44.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'JFK & LBJ: A Time for Greatness',
#     'released': '2015-08-04',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Documentary, History, Mystery',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'episode'},
#    {'title': 'The Nightly Show with Larry Wilmore',
#     'released': '2015-01-19',
#     'credit': 'self',
#     'runtime': '22 min',
#     'genre(s)': 'Comedy, News, Talk-Show',
#     'plot': 'A late night satirical talk show hosted by Larry Wilmore.',
#     'imdb_rating': 55.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Shakespeare Uncovered',
#     'released': '2012-01-25',
#     'credit': 'self',
#     'runtime': '55 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Various actors discuss Shakespeare plays. Each episode is presented by one actor and, in most cases, the actor discusses one play. However, some episodes cover more than one play. For ...',
#     'imdb_rating': 87.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Lucy: The Evolution of Lucy',
#     'released': '2015-01-20',
#     'credit': 'self',
#     'runtime': '16 min',
#     'genre(s)': 'Short',
#     'plot': 'The possible occurrence of what might happen should a person attain more than 10 percent of the brains cerebral capacity and increased cellular growth..',
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'SAG Foundation Conversations',
#     'released': '1997-07-29',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Talk-Show',
#     'plot': None,
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Late Late Show with Craig Ferguson',
#     'released': '2005-01-03',
#     'credit': 'self',
#     'runtime': '40 min',
#     'genre(s)': 'Comedy, Music, Talk-Show',
#     'plot': 'Making a satire out of the entire Late Night Show concept Scotsman Craig Ferguson hosts his show with a robot skeleton and a "horse" as his sidekicks. The show features the stereotypical parts of a Late Show, but all in their own, raw way.',
#     'imdb_rating': 83.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': '2014 Primetime Creative Arts Emmy Awards',
#     'released': '2014-08-24',
#     'credit': 'self',
#     'runtime': '205 min',
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Colbert Report',
#     'released': '2005-10-17',
#     'credit': 'self',
#     'runtime': '30 min',
#     'genre(s)': 'Comedy, News, Talk-Show',
#     'plot': 'Satirical newscaster Stephen Colbert provides humorous commentary on the big issues going on in the United States and the rest of the world, with his larger-than-life ego and overly-patriotic spirit along with him every step of the way.',
#     'imdb_rating': 85.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Up Close with Carrie Keagan',
#     'released': '2007-02-21',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Talk-Show',
#     'plot': None,
#     'imdb_rating': 53.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Island of Lemurs: Madagascar',
#     'released': '2014-09-05',
#     'credit': 'self',
#     'runtime': '39 min',
#     'genre(s)': 'Documentary, Short, Adventure, Biography, Family',
#     'plot': "A documentary that follows Dr. Patricia C. Wright's mission to help lemurs, the highly evolved creatures who arrived on Madagascar millions of years ago as castaways but are now highly endangered.",
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': 10675739.0,
#     'type': 'movie'},
#    {'title': 'Ask a Badass with Elizabeth Banks',
#     'released': '2013-11-22',
#     'credit': 'self',
#     'runtime': '4 min',
#     'genre(s)': 'Talk-Show',
#     'plot': None,
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': '20th Annual Screen Actors Guild Awards',
#     'released': '2014-01-18',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': 'Screen Actors Guild Award - American award, awarded by Guild of movie actors of the USA from 1995 for movies and television serials.',
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'JFK: A President Betrayed',
#     'released': '2013-11-12',
#     'credit': 'self',
#     'runtime': '90 min',
#     'genre(s)': 'Documentary, Drama, History, Mystery',
#     'plot': 'Narrated by Academy Award winner Morgan Freeman, "JFK: A President Betrayed" uncovers new evidence that reveals how JFK embarked on secret back channel peace efforts with Nikita Khrushchev ...',
#     'imdb_rating': 75.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Promise of a New World: The Making of 'Oblivion'",
#     'released': '2013-08-06',
#     'credit': 'self',
#     'runtime': '48 min',
#     'genre(s)': 'Documentary',
#     'plot': 'This terrific five-part "Making Of" documentary. Segments include "Destiny" (the development of the story, Iceland shoot and the film\'s practical sets), "Voyage" (the inspiration, design ...',
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'AFI Life Achievement Award: A Tribute to Mel Brooks',
#     'released': '2013-06-15',
#     'credit': 'self',
#     'runtime': '67 min',
#     'genre(s)': 'Biography',
#     'plot': None,
#     'imdb_rating': 68.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'TVGN Movie Special: Now You See Me',
#     'released': '2013-05-25',
#     'credit': 'self',
#     'runtime': '30 min',
#     'genre(s)': 'Documentary',
#     'plot': "TVGN's Movie Special: Now You See Me is a behind the scenes look at the summer blockbuster movie. From electrifying stunts, to movie secrets straight from the stars,to magic moments ...",
#     'imdb_rating': 78.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Don't Say No Until I Finish Talking: The Story of Richard D. Zanuck",
#     'released': '2013-04-28',
#     'credit': 'self',
#     'runtime': '88 min',
#     'genre(s)': 'Documentary, Biography',
#     'plot': 'A look at the life and work of legendary film producer Richard D. Zanuck.',
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': None,
# ...
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Kennedy Center Honors: A Celebration of the Performing Arts',
#     'released': '2000-12-27',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Documentary, Music',
#     'plot': None,
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Chris Rock Show',
#     'released': '1997-02-07',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Comedy, Music, Talk-Show',
#     'plot': "America's funniest comedian in a less than PC setting. It's hilarious !",
#     'imdb_rating': 68.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': "AFI's 100 Years... 100 Laughs: America's Funniest Movies",
#     'released': '2000-06-13',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Documentary',
#     'plot': None,
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 57th Annual Golden Globe Awards',
#     'released': '2000-01-01',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 45.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "AFI's 100 Years... 100 Stars: America's Greatest Screen Legends",
#     'released': '1999-06-15',
#     'credit': 'self',
#     'runtime': '135 min',
#     'genre(s)': 'Documentary',
#     'plot': "The spectacular CBS special! Shirley Temple Black hosts the festivities as 50 of today's top stars count down the 50 greatest screen legends of all time. Features Clint Eastwood, Jack Lemmon, Shirley MacLaine, Kevin Spacey and many others.",
#     'imdb_rating': 56.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '30th NAACP Image Awards',
#     'released': '1999-03-04',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 75.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Scandalize My Name: Stories from the Blacklist',
#     'released': None,
#     'credit': 'self',
#     'runtime': '54 min',
#     'genre(s)': 'Documentary',
#     'plot': 'A documentary look at the confluence of the Red scare, McCarthyism, and blacklists with the post-war activism by African Americans seeking more and better roles on radio, television, and ...',
#     'imdb_rating': 79.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '29th NAACP Image Awards',
#     'released': None,
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 51.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Long Way Home',
#     'released': '1997-09-19',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'Documentary, History, War',
#     'plot': 'The story of the post World War II Jewish refugee situation from liberation to the establishment of the modern state of Israel.',
#     'imdb_rating': 75.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '3rd Annual Screen Actors Guild Awards',
#     'released': '1997-02-22',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 63.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Kennedy Center's 25th Anniversary",
#     'released': '1996-08-18',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Cosmic Voyage',
#     'released': '1996-08-09',
#     'credit': 'self',
#     'runtime': '36 min',
#     'genre(s)': 'Documentary, Short',
#     'plot': 'Where do we fit in with the universe? This film seeks to explore our place among the ever-expanding universe.',
#     'imdb_rating': 76.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Inside the White House',
#     'released': None,
#     'credit': 'self',
#     'runtime': '90 min',
#     'genre(s)': 'Documentary, Biography, History',
#     'plot': 'A revealing look inside the most famous house in America.',
#     'imdb_rating': 67.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Promised Land',
#     'released': '1995-02-12',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Documentary',
#     'plot': 'This program documents the migration of rural Southern blacks from the segregated South to Chicago. Cultural and political gains become offset by overcrowding and increasing ghettoization, ...',
#     'imdb_rating': 75.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'A Century of Cinema',
#     'released': None,
#     'credit': 'self',
#     'runtime': '72 min',
#     'genre(s)': 'Documentary',
#     'plot': None,
#     'imdb_rating': 56.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 51st Annual Golden Globe Awards',
#     'released': '1994-01-22',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': '25th NAACP Image Awards',
#     'released': '1993-01-25',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 55.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "Eastwood & Co.: Making 'Unforgiven'",
#     'released': '2002-09-24',
#     'credit': 'self',
#     'runtime': '24 min',
#     'genre(s)': 'Documentary, Short',
#     'plot': None,
#     'imdb_rating': 70.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Arsenio Hall Show',
#     'released': '1989-01-03',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Family, Music',
#     'plot': 'Arsenio Hall hosts this hip, late-night talk show.',
#     'imdb_rating': 64.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Neglect Not the Children',
#     'released': '1991-09-09',
#     'credit': 'self',
#     'runtime': '57 min',
#     'genre(s)': 'Documentary',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 43th Annual Writers Guild Awards',
#     'released': '1991-03-20',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Reality-TV',
#     'plot': None,
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "The 17th Annual People's Choice Awards",
#     'released': None,
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 63.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 48th Annual Golden Globe Awards',
#     'released': '1991-01-19',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': "Golden Globe Award - American award awarded by the Hollywood association of the foreign press from 1944 for works in movies and television's pictures.",
#     'imdb_rating': 74.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 44th Annual Tony Awards',
#     'released': '1990-06-03',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': 'Musical',
#     'plot': None,
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 62nd Annual Academy Awards',
#     'released': '1990-03-26',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 59.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 47th Annual Golden Globe Awards',
#     'released': '1990-01-20',
#     'credit': 'self',
#     'runtime': '120 min',
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 60th Annual Academy Awards',
#     'released': '1988-04-11',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': None,
#     'plot': None,
#     'imdb_rating': 46.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Working in the Theatre',
#     'released': '1979-09-02',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary, Talk-Show',
#     'plot': 'Bringing together performers, directors, playwrights, designers, choreographers, producers and behind-the-scenes personnel from the American and international theatre, the program offers a ...',
#     'imdb_rating': 65.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Out to Lunch',
#     'released': '1974-12-10',
#     'credit': 'self',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy, Family',
#     'plot': 'The Muppets and the casts of "The Electric Company" and "Sesame Street" take over the ABC Nightly News when the newsroom staff takes a lunch break.',
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The 22nd Annual Tony Awards',
#     'released': '1968-04-21',
#     'credit': 'self',
#     'runtime': None,
#     'genre(s)': 'Family',
#     'plot': None,
#     'imdb_rating': 72.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Good Morning Britain',
#     'released': '2014-04-28',
#     'credit': 'archive_footage',
#     'runtime': '150 min',
#     'genre(s)': 'News, Talk-Show',
#     'plot': 'The weekday news on ITV that the whole nation wakes up to.',
#     'imdb_rating': 43.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Tucker Carlson Tonight',
#     'released': '2016-11-14',
#     'credit': 'archive_footage',
#     'runtime': '60 min',
#     'genre(s)': 'News, Talk-Show',
#     'plot': 'Powerful analysis and spirited debates with guests from across the political and cultural spectrum.',
#     'imdb_rating': 76.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Celebrity Page',
#     'released': '2013-09-09',
#     'credit': 'archive_footage',
#     'runtime': '30 min',
#     'genre(s)': 'News',
#     'plot': 'A look at the top stories in entertainment and celebrity news.',
#     'imdb_rating': 53.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Access Hollywood',
#     'released': '1996-09-01',
#     'credit': 'archive_footage',
#     'runtime': '30 min',
#     'genre(s)': 'News',
#     'plot': 'Celebrity information, hollywood gossip, and other news from the world of entertainment.',
#     'imdb_rating': 35.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Gruen XL',
#     'released': '2015-09-16',
#     'credit': 'archive_footage',
#     'runtime': None,
#     'genre(s)': 'Comedy, Talk-Show',
#     'plot': "The show that lifts the lid on advertising, spin and marketing. Join host Wil Anderson, stalwarts Todd Sampson and Russel Howcroft and other advertising industry experts to unpick the ways we're all bought and sold.",
#     'imdb_rating': None,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Inside Edition',
#     'released': None,
#     'credit': 'archive_footage',
#     'runtime': '30 min',
#     'genre(s)': 'Documentary, News',
#     'plot': 'Along with Hard Copy (1989) and A Current Affair (1986), this show was one of the early alternative news shows to be carried nationwide in the US. Primary stories usually focused on sex ...',
#     'imdb_rating': 39.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': "The Second Annual 'On Cinema' Oscar Special",
#     'released': '2014-03-02',
#     'credit': 'archive_footage',
#     'runtime': '119 min',
#     'genre(s)': 'Talk-Show',
#     'plot': None,
#     'imdb_rating': 86.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Fire Rises: The Creation and Impact of the Dark Knight Trilogy',
#     'released': '2013-09-24',
#     'credit': 'archive_footage',
#     'runtime': '77 min',
#     'genre(s)': 'Documentary',
#     'plot': 'Documentary about the Dark Knight Trilogy.',
#     'imdb_rating': 85.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Movie Guide',
#     'released': '2013-04-11',
#     'credit': 'archive_footage',
#     'runtime': '6 min',
#     'genre(s)': 'Action, News, Talk-Show',
#     'plot': None,
#     'imdb_rating': 82.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': "Betty White's 2nd Annual 90th Birthday",
#     'released': '2013-02-05',
#     'credit': 'archive_footage',
#     'runtime': '60 min',
#     'genre(s)': 'Comedy',
#     'plot': None,
#     'imdb_rating': 78.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'The Descendants',
#     'released': '2011-12-09',
#     'credit': 'archive_footage',
#     'runtime': '115 min',
#     'genre(s)': 'Comedy, Drama',
#     'plot': 'A land baron tries to reconnect with his two daughters after his wife is seriously injured in a boating accident.',
#     'imdb_rating': 73.0,
#     'rt_rating': None,
#     'box_office': 78500000.0,
#     'type': 'movie'},
#    {'title': 'I Am',
#     'released': '2011-02-01',
#     'credit': 'archive_footage',
#     'runtime': '78 min',
#     'genre(s)': 'Documentary',
#     'plot': "Director Tom Shadyac speaks with intellectual and spiritual leaders about what's wrong with our world and how we can improve both it and the way we live in it.",
#     'imdb_rating': 76.0,
#     'rt_rating': None,
#     'box_office': 1570251.0,
#     'type': 'movie'},
#    {'title': 'Never Sleep Again: The Elm Street Legacy',
#     'released': '2010-05-04',
#     'credit': 'archive_footage',
#     'runtime': '240 min',
#     'genre(s)': 'Documentary, Horror',
#     'plot': 'Explore the origins of "dream demon" Freddy Krueger in this award-winning documentary that takes you behind the scenes of the most frightening and imaginative horror franchise in motion picture history!',
#     'imdb_rating': 87.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Almost Famous III',
#     'released': '2010-01-02',
#     'credit': 'archive_footage',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary',
#     'plot': None,
#     'imdb_rating': 73.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': "The O'Reilly Factor",
#     'released': '1996-10-07',
#     'credit': 'archive_footage',
#     'runtime': '60 min',
#     'genre(s)': 'News, Talk-Show',
#     'plot': 'Fox News Channel news and talk show.',
#     'imdb_rating': 35.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'Today Tonight',
#     'released': None,
#     'credit': 'archive_footage',
#     'runtime': '30 min',
#     'genre(s)': 'News',
#     'plot': None,
#     'imdb_rating': 14.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': '101 Favorite Stars Way Back When',
#     'released': '2007-01-22',
#     'credit': 'archive_footage',
#     'runtime': '1 h',
#     'genre(s)': 'Biography',
#     'plot': None,
#     'imdb_rating': 58.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'},
#    {'title': 'The Another World Reunion',
#     'released': '2003-10-23',
#     'credit': 'archive_footage',
#     'runtime': None,
#     'genre(s)': 'Talk-Show',
#     'plot': None,
#     'imdb_rating': 80.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'movie'},
#    {'title': 'Biography',
#     'released': '1987-04-06',
#     'credit': 'archive_footage',
#     'runtime': '60 min',
#     'genre(s)': 'Documentary, Biography',
#     'plot': 'The life stories of various historical figures and celebrities are told.',
#     'imdb_rating': 79.0,
#     'rt_rating': None,
#     'box_office': None,
#     'type': 'series'}]}}

# %%
with open('.\\output\\query.json', 'w') as fp:
    json.dump(actordict, fp)

# %%
df = pd.DataFrame(data, columns=['Gender', 'IMDB Rank', 'Movie Title','Plot','Rating','Box Office'])
json = df.to_json(orient='records')
json
# Out:
# '[{"Gender":"male","IMDB Rank":1,"Movie Title":"The Civil War","Plot":"A comprehensive survey of the American Civil War.","Rating":91.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"The Twilight Zone","Plot":"A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.","Rating":78.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"The Atlanta Child Murders","Plot":"The city of Atlanta, Georgia, is terrorized by a rash of child murders occurring in its black community. When a black photographer is arrested for the crimes, controversy erupts over ...","Rating":67.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Ryan\'s Hope","Plot":"Set in Riverside on the upper West Side of Manhattan, Ryan\'s Hope centered mostly on the working class Ryans, an Irish-American family headed by Maeve and Johnny Ryan. They owned Ryan\'s Bar...","Rating":72.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Visions","Plot":"Weekly anthology series of original dramas, often with period settings.","Rating":59.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"The Electric Company","Plot":"A comedy variety show that teaches basic phonetic and grammar concepts using live-action sketches, cartoons, songs, and Spider-Man episodes.","Rating":82.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"New York Television Theatre","Plot":null,"Rating":null,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Madam Secretary","Plot":"A political drama which looks into the life of the Secretary of State as she tries to balance work with family.","Rating":76.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Through the Wormhole","Plot":"Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...","Rating":86.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"30 for 30","Plot":"ESPN Films\' 30 for 30 is an unprecedented documentary series featuring today\'s finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN\'s 30th ...","Rating":88.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Madam Secretary","Plot":"A political drama which looks into the life of the Secretary of State as she tries to balance work with family.","Rating":76.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Jimmy Kimmel Live!","Plot":"Jimmy Kimmel interviews celebrities.","Rating":67.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"The Late Late Show with James Corden","Plot":"Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...","Rating":63.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"The Dr. Oz Show","Plot":"Dr. Oz delivers health tips you may have received from your doctor in the form of a talk show.","Rating":47.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"CBS This Morning","Plot":"A mix of news, features and interviews with notable figures in politics, business and entertainment.","Rating":57.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Entertainment Tonight","Plot":"\\"Entertainment Tonight\\" is the #1 syndicated entertainment newsmagazine in the world. Launched in 1981, ET is anchored by Mary Hart and Bob Goen. Primary substitute anchors are Jann Carl ...","Rating":37.0,"Box Office":null},{"Gender":"male","IMDB Rank":1,"Movie Title":"Celebrity Page", ...

# %%
data
# Out:
# [('Laurence Fishburne',
#   'male',
#   95,
#   'The Civil War',
#   'A comprehensive survey of the American Civil War.',
#   91.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'The Civil War',
#   'A comprehensive survey of the American Civil War.',
#   91.0,
#   None),
#  ('Bruce Willis',
#   'male',
#   15,
#   'The Twilight Zone',
#   'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#   78.0,
#   None),
#  ('Elliott Gould',
#   'male',
#   93,
#   'The Twilight Zone',
#   'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#   78.0,
#   None),
#  ('Frances McDormand',
#   'female',
#   30,
#   'The Twilight Zone',
#   'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#   78.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'The Twilight Zone',
#   'A collection of tales which range from comic to tragic, but often have a wicked sense of humor and an unexpected twist.',
#   78.0,
#   None),
#  ('Martin Sheen',
#   'male',
#   64,
#   'The Atlanta Child Murders',
#   'The city of Atlanta, Georgia, is terrorized by a rash of child murders occurring in its black community. When a black photographer is arrested for the crimes, controversy erupts over ...',
#   67.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'The Atlanta Child Murders',
#   'The city of Atlanta, Georgia, is terrorized by a rash of child murders occurring in its black community. When a black photographer is arrested for the crimes, controversy erupts over ...',
#   67.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   "Ryan's Hope",
#   "Set in Riverside on the upper West Side of Manhattan, Ryan's Hope centered mostly on the working class Ryans, an Irish-American family headed by Maeve and Johnny Ryan. They owned Ryan's Bar...",
#   72.0,
#   None),
#  ('Christopher Lloyd',
#   'male',
#   66,
#   'Visions',
#   'Weekly anthology series of original dramas, often with period settings.',
#   59.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Visions',
#   'Weekly anthology series of original dramas, often with period settings.',
#   59.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'The Electric Company',
#   'A comedy variety show that teaches basic phonetic and grammar concepts using live-action sketches, cartoons, songs, and Spider-Man episodes.',
#   82.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'New York Television Theatre',
#   None,
#   None,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Madam Secretary',
#   'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#   76.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Madam Secretary',
#   'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#   76.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Madam Secretary',
#   'A political drama which looks into the life of the Secretary of State as she tries to balance work with family.',
#   76.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Through the Wormhole',
#   'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#   86.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Through the Wormhole',
#   'Hosted by Morgan Freeman, Through the Wormhole will explore the deepest mysteries of existence - the questions that have puzzled mankind for eternity. What are we made of? What was there ...',
#   86.0,
#   None),
#  ('Josh Brolin',
#   'male',
#   100,
#   '30 for 30',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None),
#  ('Josh Brolin',
#   'male',
#   100,
#   '30 for 30',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   '30 for 30',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   '30 for 30',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None),
#  ('Tom Hanks',
#   'male',
#   7,
#   '30 for 30',
#   "ESPN Films' 30 for 30 is an unprecedented documentary series featuring today's finest storytellers from inside and outside of the sports world. What started as a celebration of ESPN's 30th ...",
#   88.0,
#   None),
#  ('Aaron Eckhart',
#   'male',
#   79,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Adrien Brody',
#   'male',
#   88,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Al Pacino',
#   'male',
#   10,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Alan Rickman',
#   'male',
#   57,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Alec Baldwin',
#   'male',
#   67,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Allison Janney',
#   'female',
#   94,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Amy Adams',
#   'female',
#   9,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Anne Hathaway',
#   'female',
#   2,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Annette Bening',
#   'female',
#   64,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ben Affleck',
#   'male',
#   47,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ben Affleck',
#   'male',
#   47,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ben Affleck',
#   'male',
#   47,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ben Kingsley',
#   'male',
#   41,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Bill Murray',
#   'male',
#   51,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Brad Pitt',
#   'male',
#   3,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Bradley Cooper',
#   'male',
#   38,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Bruce Willis',
#   'male',
#   15,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Cameron Diaz',
#   'female',
#   59,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Cameron Diaz',
#   'female',
#   59,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Carey Mulligan',
#   'female',
#   44,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Carrie Fisher',
#   'female',
#   27,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Casey Affleck',
#   'male',
#   32,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Cate Blanchett',
#   'female',
#   10,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Catherine Keener',
#   'female',
#   56,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Catherine Zeta-Jones',
#   'female',
#   84,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Catherine Zeta-Jones',
#   'female',
#   84,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Charlize Theron',
#   'female',
#   100,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Chiwetel Ejiofor',
#   'male',
#   56,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Christoph Waltz',
#   'male',
#   49,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Christopher Lloyd',
#   'male',
#   66,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Clint Eastwood',
#   'male',
#   33,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Daniel Craig',
#   'male',
#   83,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Daryl Hannah',
#   'female',
#   34,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Denzel Washington',
#   'male',
#   39,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Diane Keaton',
#   'female',
#   4,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Diane Kruger',
#   'female',
#   60,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Don Cheadle',
#   'male',
#   72,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Don Cheadle',
#   'male',
#   72,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Dustin Hoffman',
#   'male',
#   68,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Edward Norton',
#   'male',
#   11,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Elizabeth Banks',
#   'female',
#   62,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Elle Fanning',
#   'female',
#   57,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Emma Stone',
#   'female',
#   41,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Emma Watson',
#   'female',
#   52,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ethan Hawke',
#   'male',
#   71,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ewan McGregor',
#   'male',
#   99,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Gary Oldman',
#   'male',
#   9,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Geoffrey Rush',
#   'male',
#   60,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('George Clooney',
#   'male',
#   25,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Guy Pearce',
#   'male',
#   61,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Gwyneth Paltrow',
#   'female',
#   20,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Harrison Ford',
#   'male',
#   12,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Heath Ledger',
#   'male',
#   58,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Hilary Swank',
#   'female',
#   80,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Isla Fisher',
#   'female',
#   93,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jake Gyllenhaal',
#   'male',
#   30,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jamie Foxx',
#   'male',
#   59,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jamie Foxx',
#   'male',
#   59,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jennifer Connelly',
#   'female',
#   23,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jennifer Garner',
#   'female',
#   42,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jennifer Jason Leigh',
#   'female',
#   78,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jennifer Lawrence',
#   'female',
#   7,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jeremy Renner',
#   'male',
#   76,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jessica Chastain',
#   'female',
#   13,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jim Carrey',
#   'male',
#   89,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Joaquin Phoenix',
#   'male',
#   74,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jodie Foster',
#   'female',
#   25,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('John Goodman',
#   'male',
#   65,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('John Travolta',
#   'male',
#   91,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Johnny Depp',
#   'male',
#   13,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Joseph Gordon-Levitt',
#   'male',
#   42,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Joseph Gordon-Levitt',
#   'male',
#   42,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Josh Brolin',
#   'male',
#   100,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Josh Brolin',
#   'male',
#   100,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Jude Law',
#   'male',
#   29,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Julia Roberts',
#   'female',
#   37,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kate Winslet',
#   'female',
#   14,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Katie Holmes',
#   'female',
#   71,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Keanu Reeves',
#   'male',
#   96,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Keira Knightley',
#   'female',
#   5,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kerry Washington',
#   'female',
#   58,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kevin Spacey',
#   'male',
#   17,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kirsten Dunst',
#   'female',
#   72,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kristen Stewart',
#   'female',
#   95,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kristen Wiig',
#   'female',
#   61,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Kyle Chandler',
#   'male',
#   82,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Laura Dern',
#   'female',
#   99,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Laura Linney',
#   'female',
#   63,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Laurence Fishburne',
#   'male',
#   95,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Liam Neeson',
#   'male',
#   26,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Liv Tyler',
#   'female',
#   75,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Lucy Liu',
#   'female',
#   69,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Maggie Gyllenhaal',
#   'female',
#   22,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Margot Robbie',
#   'female',
#   87,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Marion Cotillard',
#   'female',
#   11,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Marisa Tomei',
#   'female',
#   88,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Marisa Tomei',
#   'female',
#   88,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Mark Ruffalo',
#   'male',
#   24,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Mark Wahlberg',
#   'male',
#   87,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Matt Damon',
#   'male',
#   6,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Matt Damon',
#   'male',
#   6,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Matt Damon',
#   'male',
#   6,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Matthew McConaughey',
#   'male',
#   48,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Matthew McConaughey',
#   'male',
#   48,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Melissa Leo',
#   'female',
#   46,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Meryl Streep',
#   'female',
#   26,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Michael Fassbender',
#   'male',
#   52,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Michael Madsen',
#   'male',
#   54,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Michelle Monaghan',
#   'female',
#   73,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Mykelti Williamson',
#   'male',
#   69,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Naomi Watts',
#   'female',
#   39,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Naomie Harris',
#   'female',
#   36,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Natalie Portman',
#   'female',
#   1,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Nicole Kidman',
#   'female',
#   40,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Orlando Bloom',
#   'male',
#   63,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Owen Wilson',
#   'male',
#   85,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Patricia Clarkson',
#   'female',
#   53,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Paul Giamatti',
#   'male',
#   62,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Paul Giamatti',
#   'male',
#   62,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Rachel McAdams',
#   'female',
#   48,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robert De Niro',
#   'male',
#   5,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robert Downey Jr.',
#   'male',
#   80,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robert Duvall',
#   'male',
#   20,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robin Williams',
#   'male',
#   90,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robin Williams',
#   'male',
#   90,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Robin Wright',
#   'female',
#   17,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Rosanna Arquette',
#   'female',
#   54,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Russell Crowe',
#   'male',
#   31,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Ryan Gosling',
#   'male',
#   35,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Sally Field',
#   'female',
#   33,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Samuel L. Jackson',
#   'male',
#   19,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Samuel L. Jackson',
#   'male',
#   19,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Sandra Bullock',
#   'female',
#   31,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Saoirse Ronan',
#   'female',
#   79,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Sarah Paulson',
#   'female',
#   82,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Scarlett Johansson',
#   'female',
#   15,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Sigourney Weaver',
#   'female',
#   29,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Steve Buscemi',
#   'male',
#   23,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tilda Swinton',
#   'female',
#   19,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tim Robbins',
#   'male',
#   40,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tim Roth',
#   'male',
#   50,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tom Cruise',
#   'male',
#   27,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tom Cruise',
#   'male',
#   27,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Tom Hanks',
#   'male',
#   7,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Uma Thurman',
#   'female',
#   6,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Viola Davis',
#   'female',
#   50,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Vivica A. Fox',
#   'female',
#   70,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Winona Ryder',
#   'female',
#   49,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Woody Harrelson',
#   'male',
#   37,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Zach Galifianakis',
#   'male',
#   81,
#   'Jimmy Kimmel Live!',
#   'Jimmy Kimmel interviews celebrities.',
#   67.0,
#   None),
#  ('Aaron Eckhart',
#   'male',
#   79,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Alec Baldwin',
#   'male',
#   67,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Allison Janney',
#   'female',
#   94,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Amy Adams',
#   'female',
#   9,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Anne Hathaway',
#   'female',
#   2,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Annette Bening',
#   'female',
#   64,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Ben Kingsley',
#   'male',
#   41,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Benicio Del Toro',
#   'male',
#   75,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Bradley Cooper',
#   'male',
#   38,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Carey Mulligan',
#   'female',
#   44,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Casey Affleck',
#   'male',
#   32,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Cate Blanchett',
#   'female',
#   10,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Charlize Theron',
#   'female',
#   100,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Chiwetel Ejiofor',
#   'male',
#   56,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Christoph Waltz',
#   'male',
#   49,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Diane Keaton',
#   'female',
#   4,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Don Cheadle',
#   'male',
#   72,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Dustin Hoffman',
#   'male',
#   68,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Elizabeth Banks',
#   'female',
#   62,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Elle Fanning',
#   'female',
#   57,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Ellen Page',
#   'female',
#   55,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Emily Mortimer',
#   'female',
#   38,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Ethan Hawke',
#   'male',
#   71,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Ewan McGregor',
#   'male',
#   99,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Gary Oldman',
#   'male',
#   9,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Geoffrey Rush',
#   'male',
#   60,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('George Clooney',
#   'male',
#   25,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Guy Pearce',
#   'male',
#   61,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Gwyneth Paltrow',
#   'female',
#   20,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Hilary Swank',
#   'female',
#   80,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Isla Fisher',
#   'female',
#   93,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jamie Foxx',
#   'male',
#   59,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jennifer Connelly',
#   'female',
#   23,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jennifer Garner',
#   'female',
#   42,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jennifer Jason Leigh',
#   'female',
#   78,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jennifer Lawrence',
#   'female',
#   7,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jeremy Renner',
#   'male',
#   76,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jessica Chastain',
#   'female',
#   13,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jim Carrey',
#   'male',
#   89,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('John Goodman',
#   'male',
#   65,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Joseph Gordon-Levitt',
#   'male',
#   42,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Jude Law',
#   'male',
#   29,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Judi Dench',
#   'female',
#   24,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Julia Roberts',
#   'female',
#   37,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Julianne Moore',
#   'female',
#   8,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Juno Temple',
#   'female',
#   35,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Kathy Bates',
#   'female',
#   47,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Katie Holmes',
#   'female',
#   71,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Keanu Reeves',
#   'male',
#   96,
#   'The Late Late Show with James Corden',
#   'Each week night, The Late Late Show with James Corden throws a late-night after-party with a mix of celebrity guests, edgy musical acts, games and sketches. Corden differentiates his show by offering viewers a peek behind the scenes into the green room, bringing all of his guests out at once and lending his musical and acting talents to various sketches. Additionally, bandleader Reggie Watts and ...',
#   63.0,
#   None),
#  ('Keira Knightley',
#   'female',
#   5,
#   'The Late Late Show with James Corden',
# ...
#   'male',
#   48,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Melissa Leo',
#   'female',
#   46,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Meryl Streep',
#   'female',
#   26,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Michael Caine',
#   'male',
#   4,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Michelle Monaghan',
#   'female',
#   73,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Michelle Pfeiffer',
#   'female',
#   98,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Naomi Watts',
#   'female',
#   39,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Natalie Portman',
#   'female',
#   1,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Nicole Kidman',
#   'female',
#   40,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Orlando Bloom',
#   'male',
#   63,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Patricia Clarkson',
#   'female',
#   53,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Paul Giamatti',
#   'male',
#   62,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Ralph Fiennes',
#   'male',
#   16,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Robert De Niro',
#   'male',
#   5,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Robert Downey Jr.',
#   'male',
#   80,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Robin Williams',
#   'male',
#   90,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Robin Williams',
#   'male',
#   90,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Russell Crowe',
#   'male',
#   31,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Sally Field',
#   'female',
#   33,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Samuel L. Jackson',
#   'male',
#   19,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Sandra Bullock',
#   'female',
#   31,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Sarah Paulson',
#   'female',
#   82,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Sigourney Weaver',
#   'female',
#   29,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Stanley Tucci',
#   'male',
#   77,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Tim Robbins',
#   'male',
#   40,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Tom Cruise',
#   'male',
#   27,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Toni Collette',
#   'female',
#   51,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Uma Thurman',
#   'female',
#   6,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Viola Davis',
#   'female',
#   50,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Vivica A. Fox',
#   'female',
#   70,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Woody Harrelson',
#   'male',
#   37,
#   'The View',
#   'A panel of four real women discuss everyday issues, share their opinions and engage in colorful conversations for a variety of topics.',
#   28.0,
#   None),
#  ('Aaron Eckhart',
#   'male',
#   79,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Alec Baldwin',
#   'male',
#   67,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Allison Janney',
#   'female',
#   94,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Amy Adams',
#   'female',
#   9,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Anne Hathaway',
#   'female',
#   2,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Ben Kingsley',
#   'male',
#   41,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Benicio Del Toro',
#   'male',
#   75,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Bradley Cooper',
#   'male',
#   38,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Cameron Diaz',
#   'female',
#   59,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Carey Mulligan',
#   'female',
#   44,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Casey Affleck',
#   'male',
#   32,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Catherine Zeta-Jones',
#   'female',
#   84,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Charlize Theron',
#   'female',
#   100,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Chiwetel Ejiofor',
#   'male',
#   56,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Christoph Waltz',
#   'male',
#   49,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Daniel Craig',
#   'male',
#   83,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Diane Kruger',
#   'female',
#   60,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Don Cheadle',
#   'male',
#   72,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Edward Norton',
#   'male',
#   11,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Elle Fanning',
#   'female',
#   57,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Ellen Page',
#   'female',
#   55,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Emma Stone',
#   'female',
#   41,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Ethan Hawke',
#   'male',
#   71,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Ewan McGregor',
#   'male',
#   99,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Gary Oldman',
#   'male',
#   9,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jake Gyllenhaal',
#   'male',
#   30,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jennifer Connelly',
#   'female',
#   23,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jennifer Garner',
#   'female',
#   42,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jennifer Jason Leigh',
#   'female',
#   78,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jennifer Lawrence',
#   'female',
#   7,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('John Carroll Lynch',
#   'male',
#   45,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('John Carroll Lynch',
#   'male',
#   45,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('John Goodman',
#   'male',
#   65,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Joseph Gordon-Levitt',
#   'male',
#   42,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Josh Brolin',
#   'male',
#   100,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Jude Law',
#   'male',
#   29,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Julianne Moore',
#   'female',
#   8,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kate Winslet',
#   'female',
#   14,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kathy Bates',
#   'female',
#   47,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Keira Knightley',
#   'female',
#   5,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kerry Washington',
#   'female',
#   58,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kevin Spacey',
#   'male',
#   17,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kirsten Dunst',
#   'female',
#   72,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kristen Stewart',
#   'female',
#   95,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kristen Wiig',
#   'female',
#   61,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Kyle Chandler',
#   'male',
#   82,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Laura Dern',
#   'female',
#   99,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Lucy Liu',
#   'female',
#   69,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Maggie Gyllenhaal',
#   'female',
#   22,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Mark Wahlberg',
#   'male',
#   87,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Mary Steenburgen',
#   'female',
#   97,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Matthew McConaughey',
#   'male',
#   48,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Melissa Leo',
#   'female',
#   46,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Meryl Streep',
#   'female',
#   26,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Michael Fassbender',
#   'male',
#   52,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Michael Fassbender',
#   'male',
#   52,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Michelle Monaghan',
#   'female',
#   73,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Morgan Freeman',
#   'male',
#   1,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Naomi Watts',
#   'female',
#   39,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Natalie Portman',
#   'female',
#   1,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Patricia Clarkson',
#   'female',
#   53,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Paul Giamatti',
#   'male',
#   62,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Ralph Fiennes',
#   'male',
#   16,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Robert De Niro',
#   'male',
#   5,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Robert Downey Jr.',
#   'male',
#   80,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Robert Duvall',
#   'male',
#   20,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Rooney Mara',
#   'female',
#   65,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Rosamund Pike',
#   'female',
#   85,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Russell Crowe',
#   'male',
#   31,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ('Sally Field',
#   'female',
#   33,
#   'Late Night with Seth Meyers',
#   'Seth Meyers hosts a late-night talk show.',
#   60.0,
#   None),
#  ...]

# %%
dropdown = session.query(Actor.name,Actor.gender).distinct().all()
len(dropdown)
# Out:
# 200

# %%
dropdownlist = []

for this in dropdown:
    dropdowndict = {}
    dropdowndict["name"] = (this[0])
    dropdowndict["gender"] = (f"{(this[1])[0].upper()}{(this[1])[1:4]}")
    dropdownlist.append(dropdowndict)  
    
dropdownlist
# Out:
# [{'name': 'Morgan Freeman', 'gender': 'Male'},
#  {'name': 'Leonardo DiCaprio', 'gender': 'Male'},
#  {'name': 'Brad Pitt', 'gender': 'Male'},
#  {'name': 'Michael Caine', 'gender': 'Male'},
#  {'name': 'Robert De Niro', 'gender': 'Male'},
#  {'name': 'Matt Damon', 'gender': 'Male'},
#  {'name': 'Tom Hanks', 'gender': 'Male'},
#  {'name': 'Christian Bale', 'gender': 'Male'},
#  {'name': 'Gary Oldman', 'gender': 'Male'},
#  {'name': 'Al Pacino', 'gender': 'Male'},
#  {'name': 'Edward Norton', 'gender': 'Male'},
#  {'name': 'Harrison Ford', 'gender': 'Male'},
#  {'name': 'Johnny Depp', 'gender': 'Male'},
#  {'name': 'Cillian Murphy', 'gender': 'Male'},
#  {'name': 'Bruce Willis', 'gender': 'Male'},
#  {'name': 'Ralph Fiennes', 'gender': 'Male'},
#  {'name': 'Kevin Spacey', 'gender': 'Male'},
#  {'name': 'Jack Nicholson', 'gender': 'Male'},
#  {'name': 'Samuel L. Jackson', 'gender': 'Male'},
#  {'name': 'Robert Duvall', 'gender': 'Male'},
#  {'name': 'Philip Seymour Hoffman', 'gender': 'Male'},
#  {'name': 'Tom Hardy', 'gender': 'Male'},
#  {'name': 'Steve Buscemi', 'gender': 'Male'},
#  {'name': 'Mark Ruffalo', 'gender': 'Male'},
#  {'name': 'George Clooney', 'gender': 'Male'},
#  {'name': 'Liam Neeson', 'gender': 'Male'},
#  {'name': 'Tom Cruise', 'gender': 'Male'},
#  {'name': 'Hugo Weaving', 'gender': 'Male'},
#  {'name': 'Jude Law', 'gender': 'Male'},
#  {'name': 'Jake Gyllenhaal', 'gender': 'Male'},
#  {'name': 'Russell Crowe', 'gender': 'Male'},
#  {'name': 'Casey Affleck', 'gender': 'Male'},
#  {'name': 'Clint Eastwood', 'gender': 'Male'},
#  {'name': 'Harvey Keitel', 'gender': 'Male'},
#  {'name': 'Ryan Gosling', 'gender': 'Male'},
#  {'name': 'Tom Wilkinson', 'gender': 'Male'},
#  {'name': 'Woody Harrelson', 'gender': 'Male'},
#  {'name': 'Bradley Cooper', 'gender': 'Male'},
#  {'name': 'Denzel Washington', 'gender': 'Male'},
#  {'name': 'Tim Robbins', 'gender': 'Male'},
#  {'name': 'Ben Kingsley', 'gender': 'Male'},
#  {'name': 'Joseph Gordon-Levitt', 'gender': 'Male'},
#  {'name': 'John Hurt', 'gender': 'Male'},
#  {'name': 'John Cazale', 'gender': 'Male'},
#  {'name': 'John Carroll Lynch', 'gender': 'Male'},
#  {'name': 'Ed Harris', 'gender': 'Male'},
#  {'name': 'Ben Affleck', 'gender': 'Male'},
#  {'name': 'Matthew McConaughey', 'gender': 'Male'},
#  {'name': 'Christoph Waltz', 'gender': 'Male'},
#  {'name': 'Tim Roth', 'gender': 'Male'},
#  {'name': 'Bill Murray', 'gender': 'Male'},
#  {'name': 'Michael Fassbender', 'gender': 'Male'},
#  {'name': 'Pete Postlethwaite', 'gender': 'Male'},
#  {'name': 'Michael Madsen', 'gender': 'Male'},
#  {'name': 'Barry Pepper', 'gender': 'Male'},
#  {'name': 'Chiwetel Ejiofor', 'gender': 'Male'},
#  {'name': 'Alan Rickman', 'gender': 'Male'},
#  {'name': 'Heath Ledger', 'gender': 'Male'},
#  {'name': 'Jamie Foxx', 'gender': 'Male'},
#  {'name': 'Geoffrey Rush', 'gender': 'Male'},
#  {'name': 'Guy Pearce', 'gender': 'Male'},
#  {'name': 'Paul Giamatti', 'gender': 'Male'},
#  {'name': 'Orlando Bloom', 'gender': 'Male'},
#  {'name': 'Martin Sheen', 'gender': 'Male'},
#  {'name': 'John Goodman', 'gender': 'Male'},
#  {'name': 'Christopher Lloyd', 'gender': 'Male'},
#  {'name': 'Alec Baldwin', 'gender': 'Male'},
#  {'name': 'Dustin Hoffman', 'gender': 'Male'},
#  {'name': 'Mykelti Williamson', 'gender': 'Male'},
#  {'name': 'Joe Pesci', 'gender': 'Male'},
#  {'name': 'Ethan Hawke', 'gender': 'Male'},
#  {'name': 'Don Cheadle', 'gender': 'Male'},
#  {'name': 'Stellan Skarsgård', 'gender': 'Male'},
#  {'name': 'Joaquin Phoenix', 'gender': 'Male'},
#  {'name': 'Benicio Del Toro', 'gender': 'Male'},
#  {'name': 'Jeremy Renner', 'gender': 'Male'},
#  {'name': 'Stanley Tucci', 'gender': 'Male'},
#  {'name': 'Marlon Brando', 'gender': 'Male'},
#  {'name': 'Aaron Eckhart', 'gender': 'Male'},
#  {'name': 'Robert Downey Jr.', 'gender': 'Male'},
#  {'name': 'Zach Galifianakis', 'gender': 'Male'},
#  {'name': 'Kyle Chandler', 'gender': 'Male'},
#  {'name': 'Daniel Craig', 'gender': 'Male'},
#  {'name': 'Ken Watanabe', 'gender': 'Male'},
#  {'name': 'Owen Wilson', 'gender': 'Male'},
#  {'name': 'Max von Sydow', 'gender': 'Male'},
#  {'name': 'Mark Wahlberg', 'gender': 'Male'},
#  {'name': 'Adrien Brody', 'gender': 'Male'},
#  {'name': 'Jim Carrey', 'gender': 'Male'},
#  {'name': 'Robin Williams', 'gender': 'Male'},
#  {'name': 'John Travolta', 'gender': 'Male'},
#  {'name': 'Tom Sizemore', 'gender': 'Male'},
#  {'name': 'Elliott Gould', 'gender': 'Male'},
#  {'name': 'Richard Harris', 'gender': 'Male'},
#  {'name': 'Laurence Fishburne', 'gender': 'Male'},
#  {'name': 'Keanu Reeves', 'gender': 'Male'},
#  {'name': 'Ian Holm', 'gender': 'Male'},
#  {'name': 'Sean Connery', 'gender': 'Male'},
#  {'name': 'Ewan McGregor', 'gender': 'Male'},
#  {'name': 'Josh Brolin', 'gender': 'Male'},
#  {'name': 'Natalie Portman', 'gender': 'Fema'},
#  {'name': 'Anne Hathaway', 'gender': 'Fema'},
#  {'name': 'Talia Shire', 'gender': 'Fema'},
#  {'name': 'Diane Keaton', 'gender': 'Fema'},
#  {'name': 'Keira Knightley', 'gender': 'Fema'},
#  {'name': 'Uma Thurman', 'gender': 'Fema'},
#  {'name': 'Jennifer Lawrence', 'gender': 'Fema'},
#  {'name': 'Julianne Moore', 'gender': 'Fema'},
#  {'name': 'Amy Adams', 'gender': 'Fema'},
#  {'name': 'Cate Blanchett', 'gender': 'Fema'},
#  {'name': 'Marion Cotillard', 'gender': 'Fema'},
#  {'name': 'Helena Bonham Carter', 'gender': 'Fema'},
#  {'name': 'Jessica Chastain', 'gender': 'Fema'},
#  {'name': 'Kate Winslet', 'gender': 'Fema'},
#  {'name': 'Scarlett Johansson', 'gender': 'Fema'},
#  {'name': 'Léa Seydoux', 'gender': 'Fema'},
#  {'name': 'Robin Wright', 'gender': 'Fema'},
#  {'name': 'Vera Farmiga', 'gender': 'Fema'},
#  {'name': 'Tilda Swinton', 'gender': 'Fema'},
#  {'name': 'Gwyneth Paltrow', 'gender': 'Fema'},
#  {'name': 'Carrie-Anne Moss', 'gender': 'Fema'},
#  {'name': 'Maggie Gyllenhaal', 'gender': 'Fema'},
#  {'name': 'Jennifer Connelly', 'gender': 'Fema'},
#  {'name': 'Judi Dench', 'gender': 'Fema'},
#  {'name': 'Jodie Foster', 'gender': 'Fema'},
#  {'name': 'Meryl Streep', 'gender': 'Fema'},
#  {'name': 'Carrie Fisher', 'gender': 'Fema'},
#  {'name': 'Amanda Plummer', 'gender': 'Fema'},
#  {'name': 'Sigourney Weaver', 'gender': 'Fema'},
#  {'name': 'Frances McDormand', 'gender': 'Fema'},
#  {'name': 'Sandra Bullock', 'gender': 'Fema'},
#  {'name': 'Rebecca Hall', 'gender': 'Fema'},
#  {'name': 'Sally Field', 'gender': 'Fema'},
#  {'name': 'Daryl Hannah', 'gender': 'Fema'},
#  {'name': 'Juno Temple', 'gender': 'Fema'},
#  {'name': 'Naomie Harris', 'gender': 'Fema'},
#  {'name': 'Julia Roberts', 'gender': 'Fema'},
#  {'name': 'Emily Mortimer', 'gender': 'Fema'},
#  {'name': 'Naomi Watts', 'gender': 'Fema'},
#  {'name': 'Nicole Kidman', 'gender': 'Fema'},
#  {'name': 'Emma Stone', 'gender': 'Fema'},
#  {'name': 'Jennifer Garner', 'gender': 'Fema'},
#  {'name': 'Michelle Williams', 'gender': 'Fema'},
#  {'name': 'Carey Mulligan', 'gender': 'Fema'},
#  {'name': 'Mélanie Laurent', 'gender': 'Fema'},
#  {'name': 'Melissa Leo', 'gender': 'Fema'},
#  {'name': 'Kathy Bates', 'gender': 'Fema'},
#  {'name': 'Rachel McAdams', 'gender': 'Fema'},
#  {'name': 'Winona Ryder', 'gender': 'Fema'},
#  {'name': 'Viola Davis', 'gender': 'Fema'},
#  {'name': 'Toni Collette', 'gender': 'Fema'},
#  {'name': 'Emma Watson', 'gender': 'Fema'},
#  {'name': 'Patricia Clarkson', 'gender': 'Fema'},
#  {'name': 'Rosanna Arquette', 'gender': 'Fema'},
#  {'name': 'Ellen Page', 'gender': 'Fema'},
#  {'name': 'Catherine Keener', 'gender': 'Fema'},
#  {'name': 'Elle Fanning', 'gender': 'Fema'},
#  {'name': 'Kerry Washington', 'gender': 'Fema'},
#  {'name': 'Cameron Diaz', 'gender': 'Fema'},
#  {'name': 'Diane Kruger', 'gender': 'Fema'},
#  {'name': 'Kristen Wiig', 'gender': 'Fema'},
#  {'name': 'Elizabeth Banks', 'gender': 'Fema'},
#  {'name': 'Laura Linney', 'gender': 'Fema'},
#  {'name': 'Annette Bening', 'gender': 'Fema'},
#  {'name': 'Rooney Mara', 'gender': 'Fema'},
#  {'name': 'Maggie Smith', 'gender': 'Fema'},
#  {'name': 'Penélope Cruz', 'gender': 'Fema'},
#  {'name': 'Olivia Williams', 'gender': 'Fema'},
#  {'name': 'Lucy Liu', 'gender': 'Fema'},
#  {'name': 'Vivica A. Fox', 'gender': 'Fema'},
#  {'name': 'Katie Holmes', 'gender': 'Fema'},
#  {'name': 'Kirsten Dunst', 'gender': 'Fema'},
#  {'name': 'Michelle Monaghan', 'gender': 'Fema'},
#  {'name': 'Kelly Macdonald', 'gender': 'Fema'},
#  {'name': 'Liv Tyler', 'gender': 'Fema'},
#  {'name': 'Jennifer Ehle', 'gender': 'Fema'},
#  {'name': 'Lea Thompson', 'gender': 'Fema'},
#  {'name': 'Jennifer Jason Leigh', 'gender': 'Fema'},
#  {'name': 'Saoirse Ronan', 'gender': 'Fema'},
#  {'name': 'Hilary Swank', 'gender': 'Fema'},
#  {'name': 'Amy Ryan', 'gender': 'Fema'},
#  {'name': 'Sarah Paulson', 'gender': 'Fema'},
#  {'name': 'Ellen Burstyn', 'gender': 'Fema'},
#  {'name': 'Catherine Zeta-Jones', 'gender': 'Fema'},
#  {'name': 'Rosamund Pike', 'gender': 'Fema'},
#  {'name': 'Marcia Gay Harden', 'gender': 'Fema'},
#  {'name': 'Margot Robbie', 'gender': 'Fema'},
#  {'name': 'Marisa Tomei', 'gender': 'Fema'},
#  {'name': 'Adam Tomei', 'gender': 'Fema'},
#  {'name': 'Franka Potente', 'gender': 'Fema'},
#  {'name': 'Karen Allen', 'gender': 'Fema'},
#  {'name': 'Frances Fisher', 'gender': 'Fema'},
#  {'name': 'Isla Fisher', 'gender': 'Fema'},
#  {'name': 'Allison Janney', 'gender': 'Fema'},
#  {'name': 'Kristen Stewart', 'gender': 'Fema'},
#  {'name': "Beverly D'Angelo", 'gender': 'Fema'},
#  {'name': 'Mary Steenburgen', 'gender': 'Fema'},
#  {'name': 'Michelle Pfeiffer', 'gender': 'Fema'},
#  {'name': 'Laura Dern', 'gender': 'Fema'},
#  {'name': 'Charlize Theron', 'gender': 'Fema'}]
